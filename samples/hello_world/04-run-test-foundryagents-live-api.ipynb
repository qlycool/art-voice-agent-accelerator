# %% [markdown]
# # **Azure Voice Live API: Real-Time Voice Agents**
#
# This notebook demonstrates enterprise-grade real-time voice conversation implementation using Azure Voice Live API with Azure AI Agent Service integration.
#
# ### **Notebook Architecture Overview**
# ```
# ┌─────────────────┐    ┌──────────────────┐    ┌─────────────────────┐
# │   Audio I/O     │◄──►│  WebSocket Client │◄──►│ Azure AI Agent      │
# │  (sounddevice)  │    │  (Threading)     │    │ Service + Voice API │
# └─────────────────┘    └──────────────────┘    └─────────────────────┘
# ```
#
# ### **Implementation Progression**
# 1. **Core Infrastructure** - WebSocket connection & audio processing
# 2. **Authentication & Configuration** - Entra ID + API key fallback
# 3. **Direct Model Integration** - Basic voice live API connection
# 4. **Azure AI Agent Service** - Production agent-based architecture
# 5. **Production Deployment** - Complete application with proper cleanup
#
# ### **Key Features**
# - **Low-latency audio streaming** (24kHz, 20ms chunks)
# - **Semantic VAD** with Azure deep noise suppression
# - **Thread-safe audio processing** with graceful shutdown
# - **Dual authentication** (Entra ID + API key)
# - **Agent-based architecture** for enterprise scalability

# %% [markdown]
# ## **1. Dependencies & Core Imports**

# %%
# Core Python libraries
import os
import uuid
import json
import time
import base64
import logging
import threading
import queue
import signal
import sys
from collections import deque
from datetime import datetime

# Audio processing
import numpy as np
import sounddevice as sd

# Azure SDK and authentication
from dotenv import load_dotenv
from azure.core.credentials import TokenCredential
from azure.identity import DefaultAzureCredential

# Type hints
from typing import Dict, Union, Literal, Set
from typing_extensions import Iterator, TypedDict, Required

# WebSocket communication
import websocket
from websocket import WebSocketApp

print("✅ All dependencies imported successfully!")
# Out:
# ✅ All dependencies imported successfully!

# %% [markdown]
# ## **2. Configuration & Environment**

# %%
# Load environment variables
load_dotenv("./.env", override=True)

# Global variables for thread coordination
stop_event = threading.Event()
connection_queue = queue.Queue()

# Audio configuration
AUDIO_SAMPLE_RATE = 24000

# Logger setup
logger = logging.getLogger(__name__)

# Voice Live API configuration
AZURE_VOICE_LIVE_ENDPOINT = os.environ.get("AZURE_VOICE_LIVE_ENDPOINT") or "https://aifoundry825233136833-resource.services.ai.azure.com"
AZURE_VOICE_LIVE_MODEL = os.environ.get("AZURE_VOICE_LIVE_MODEL") or "gpt-4o"
AZURE_VOICE_LIVE_API_VERSION = os.environ.get("AZURE_VOICE_LIVE_API_VERSION") or "2025-05-01-preview"
AZURE_VOICE_LIVE_API_KEY = os.environ.get("AZURE_VOICE_LIVE_API_KEY")

# Azure AI Agent Service configuration
AI_FOUNDRY_PROJECT_NAME = os.environ.get("AI_FOUNDRY_PROJECT_NAME")
AI_FOUNDRY_AGENT_ID = os.environ.get("AI_FOUNDRY_AGENT_ID")
AI_FOUNDRY_AGENT_CONNECTION_STRING = os.environ.get("AI_FOUNDRY_AGENT_CONNECTION_STRING")

print("📋 Voice Live API Configuration:")
print(f"  - Endpoint: {AZURE_VOICE_LIVE_ENDPOINT}")
print(f"  - Model: {AZURE_VOICE_LIVE_MODEL}")
print(f"  - API Version: {AZURE_VOICE_LIVE_API_VERSION}")
print(f"  - API Key: {'✅ Configured' if AZURE_VOICE_LIVE_API_KEY else '❌ Not set'}")

print("\n🤖 Azure AI Agent Service Configuration:")
print(f"  - Project Name: {AI_FOUNDRY_PROJECT_NAME or '❌ Not set'}")
print(f"  - Agent ID: {AI_FOUNDRY_AGENT_ID or '❌ Not set'}")
print(f"  - Connection String: {'✅ Configured' if AI_FOUNDRY_AGENT_CONNECTION_STRING else '❌ Not set (hub-based only)'}")

print(f"\n🎛️  Audio Sample Rate: {AUDIO_SAMPLE_RATE} Hz")
# Out:
# 📋 Voice Live API Configuration:
#   - Endpoint: https://poc-ai-agents-voice-resource.cognitiveservices.azure.com/
#   - Model: gpt-4o
#   - API Version: 2025-05-01-preview
#   - API Key: ✅ Configured
#
# 🤖 Azure AI Agent Service Configuration:
#   - Project Name: poc-ai-agents-voice
#   - Agent ID: asst_Dd9U7mxFgfZxjwhEbSr76dyU
#   - Connection String: ❌ Not set (hub-based only)
#
# 🎛️  Audio Sample Rate: 24000 Hz

# %% [markdown]
# ## **3. WebSocket Connection Management**
#
# Thread-safe WebSocket client with message queuing and connection state management.

# %%
class VoiceLiveConnection:
    """
    Manages WebSocket connection to Azure Voice Live API.
    
    Features:
    - Asynchronous message handling
    - Thread-safe message queue
    - Connection state management
    - Error handling and logging
    """
    
    def __init__(self, url: str, headers: dict) -> None:
        self._url = url
        self._headers = headers
        self._ws = None
        self._message_queue = queue.Queue()
        self._connected = False
        self._connection_id = str(uuid.uuid4())[:8]
        self._message_count = 0

    def connect(self) -> None:
        """Establish WebSocket connection with event handlers."""
        
        if self._connected:
            logger.warning("Connection already established")
            return
            
        print(f"🔌 Establishing WebSocket connection (ID: {self._connection_id})...")
        
        def on_message(ws, message):
            """Handle incoming messages by adding them to the queue."""
            self._message_count += 1
            self._message_queue.put(message)
            logger.debug(f"Connection {self._connection_id}: Message #{self._message_count} queued")
        
        def on_error(ws, error):
            """Handle WebSocket errors."""
            print(f"❌ WebSocket error (ID: {self._connection_id}): {error}")
            logger.error(f"Connection {self._connection_id}: WebSocket error: {error}")
        
        def on_close(ws, close_status_code, close_msg):
            """Handle connection closure."""
            print(f"🔌 WebSocket connection closed (ID: {self._connection_id})")
            print(f"   Status: {close_status_code}, Message: {close_msg}")
            logger.info(f"Connection {self._connection_id}: WebSocket closed - {close_status_code}: {close_msg}")
            self._connected = False
        
        def on_open(ws):
            """Handle successful connection."""
            print(f"✅ WebSocket connection opened (ID: {self._connection_id})")
            logger.info(f"Connection {self._connection_id}: WebSocket opened")
            self._connected = True

        # Create WebSocket app with event handlers
        self._ws = websocket.WebSocketApp(
            self._url,
            header=self._headers,
            on_message=on_message,
            on_error=on_error,
            on_close=on_close,
            on_open=on_open
        )
        
        # Start WebSocket in a separate thread
        self._ws_thread = threading.Thread(
            target=self._ws.run_forever, 
            name=f"WebSocket-{self._connection_id}"
        )
        self._ws_thread.daemon = True
        self._ws_thread.start()
        
        # Wait for connection to be established
        timeout = 10  # seconds
        start_time = time.time()
        while not self._connected and time.time() - start_time < timeout:
            time.sleep(0.1)
        
        if not self._connected:
            raise ConnectionError(f"Failed to establish WebSocket connection (ID: {self._connection_id}) within {timeout} seconds")
        
        print(f"✅ Connection established successfully (ID: {self._connection_id})")

    def recv(self) -> str:
        """Receive a message from the queue (non-blocking with timeout)."""
        try:
            message = self._message_queue.get(timeout=1)
            logger.debug(f"Connection {self._connection_id}: Message received from queue")
            return message
        except queue.Empty:
            return None

    def send(self, message: str) -> None:
        """Send a message through the WebSocket."""
        if self._ws and self._connected:
            self._ws.send(message)
            logger.debug(f"Connection {self._connection_id}: Message sent")
        else:
            logger.warning(f"Connection {self._connection_id}: Cannot send - not connected")
            print(f"⚠️  Cannot send message - connection not established (ID: {self._connection_id})")

    def close(self) -> None:
        """Close the WebSocket connection."""
        if self._ws:
            print(f"🔌 Closing WebSocket connection (ID: {self._connection_id})...")
            logger.info(f"Connection {self._connection_id}: Closing connection")
            self._ws.close()
            self._connected = False
            
            # Wait for thread to finish
            if hasattr(self, '_ws_thread') and self._ws_thread.is_alive():
                self._ws_thread.join(timeout=3)
                if self._ws_thread.is_alive():
                    print(f"⚠️  WebSocket thread did not stop gracefully (ID: {self._connection_id})")
                else:
                    print(f"✅ WebSocket thread stopped (ID: {self._connection_id})")
            
            print(f"✅ Connection closed (ID: {self._connection_id}, {self._message_count} messages processed)")
        else:
            print(f"ℹ️  No connection to close (ID: {self._connection_id})")

    @property
    def connection_id(self) -> str:
        """Get the connection ID for debugging."""
        return self._connection_id
    
    @property
    def is_connected(self) -> bool:
        """Check if the connection is active."""
        return self._connected
    
    @property
    def message_count(self) -> int:
        """Get the number of messages processed."""
        return self._message_count

print("✅ Enhanced VoiceLiveConnection class with connection state management")
# Out:
# ✅ Enhanced VoiceLiveConnection class with connection state management

# %% [markdown]
# ## **4. Azure Voice Live Client**
#
# Main client supporting both direct model and agent connections.

# %%
class AzureVoiceLive:
    """
    Main client for Azure Voice Live API.
    
    Handles:
    - Authentication (API key or token-based)
    - Connection management
    - URL construction for WebSocket endpoint
    """
    
    def __init__(
        self,
        *,
        azure_endpoint: str | None = None,
        api_version: str | None = None,
        token: str | None = None,
        api_key: str | None = None,
    ) -> None:
        self._azure_endpoint = azure_endpoint
        self._api_version = api_version
        self._token = token
        self._api_key = api_key
        self._connection = None

    def connect(self, model: str) -> VoiceLiveConnection:
        """
        Create a connection to the Voice Live API.
        
        Args:
            model: The AI model to use (e.g., 'gpt-4o')
            
        Returns:
            VoiceLiveConnection: Ready-to-use connection object
        """
        # if self._connection is not None:
        #     raise ValueError("Already connected to the Voice Live API.")
        if not model:
            raise ValueError("Model name is required.")

        # Convert HTTPS endpoint to WSS for WebSocket
        azure_ws_endpoint = self._azure_endpoint.rstrip('/').replace("https://", "wss://")

        # Construct WebSocket URL
        url = f"{azure_ws_endpoint}/voice-live/realtime?api-version={self._api_version}&model={model}"

        # Setup authentication headers
        auth_header = {"Authorization": f"Bearer {self._token}"} if self._token else {"api-key": self._api_key}
        request_id = uuid.uuid4()
        headers = {"x-ms-client-request-id": str(request_id), **auth_header}

        # Create and connect
        self._connection = VoiceLiveConnection(url, headers)
        self._connection.connect()
        return self._connection

print("✅ AzureVoiceLive client class defined")
# Out:
# ✅ AzureVoiceLive client class defined

# %% [markdown]
# ## **5. Real-Time Audio Processing**
#
# Low-latency audio player with deque-based buffering for real-time streaming.

# %%
class AudioPlayerAsync:
    """
    Asynchronous audio player with buffering for real-time playback.
    
    Features:
    - Thread-safe audio queue
    - Real-time streaming playback
    - Automatic start/stop management
    - Low-latency audio processing
    """
    
    def __init__(self):
        self.queue = deque()
        self.lock = threading.Lock()
        self.stream = sd.OutputStream(
            callback=self.callback,
            samplerate=AUDIO_SAMPLE_RATE,
            channels=1,
            dtype=np.int16,
            blocksize=2400,  # ~100ms at 24kHz
        )
        self.playing = False

    def callback(self, outdata, frames, time, status):
        """
        Audio callback function called by sounddevice.
        
        This function is called in real-time by the audio system
        and must be very efficient to avoid dropouts.
        """
        if status:
            logger.warning(f"Stream status: {status}")
            
        with self.lock:
            data = np.empty(0, dtype=np.int16)
            
            # Fill the output buffer from our queue
            while len(data) < frames and len(self.queue) > 0:
                item = self.queue.popleft()
                frames_needed = frames - len(data)
                data = np.concatenate((data, item[:frames_needed]))
                
                # If we have leftover data, put it back
                if len(item) > frames_needed:
                    self.queue.appendleft(item[frames_needed:])
            
            # Pad with silence if we don't have enough data
            if len(data) < frames:
                data = np.concatenate((data, np.zeros(frames - len(data), dtype=np.int16)))
                
        outdata[:] = data.reshape(-1, 1)

    def add_data(self, data: bytes):
        """Add audio data to the playback queue."""
        with self.lock:
            np_data = np.frombuffer(data, dtype=np.int16)
            self.queue.append(np_data)
            
            # Auto-start playback if we have data
            if not self.playing and len(self.queue) > 0:
                self.start()

    def start(self):
        """Start audio playback."""
        if not self.playing:
            self.playing = True
            self.stream.start()

    def stop(self):
        """Stop audio playback and clear buffer."""
        with self.lock:
            self.queue.clear()
        self.playing = False
        self.stream.stop()

    def terminate(self):
        """Terminate the audio player and release resources."""
        with self.lock:
            self.queue.clear()
        self.stream.stop()
        self.stream.close()

print("✅ AudioPlayerAsync class defined")
# Out:
# ✅ AudioPlayerAsync class defined

# %% [markdown]
# ## **6. Audio Input Capture**
#
# Microphone capture with base64 encoding for WebSocket transmission.

# %%
def listen_and_send_audio(connection: VoiceLiveConnection) -> None:
    """
    Capture audio from microphone and send to Voice Live API.
    
    This function runs in a separate thread and continuously:
    1. Reads audio from the microphone
    2. Encodes it as base64
    3. Sends it to the API via WebSocket
    
    Args:
        connection: Active VoiceLiveConnection instance
    """
    logger.info("Starting audio stream ...")

    # Create audio input stream
    stream = sd.InputStream(
        channels=1, 
        samplerate=AUDIO_SAMPLE_RATE, 
        dtype="int16"
    )
    
    try:
        stream.start()
        
        # Read audio in 20ms chunks (480 samples at 24kHz)
        read_size = int(AUDIO_SAMPLE_RATE * 0.02)
        
        while not stop_event.is_set():
            if stream.read_available >= read_size:
                # Read audio data
                data, _ = stream.read(read_size)
                
                # Encode as base64
                audio = base64.b64encode(data).decode("utf-8")
                
                # Create API message
                param = {
                    "type": "input_audio_buffer.append", 
                    "audio": audio, 
                    "event_id": ""
                }
                
                # Send to API
                data_json = json.dumps(param)
                connection.send(data_json)
            else:
                time.sleep(0.001)  # Small sleep to prevent busy waiting
                
    except Exception as e:
        logger.error(f"Audio stream interrupted. {e}")
    finally:
        stream.stop()
        stream.close()
        logger.info("Audio stream closed.")

print("✅ Audio input function defined")
# Out:
# ✅ Audio input function defined

# %% [markdown]
# ## **7. Audio Output & Event Processing**
#
# WebSocket event handler with audio playback and conversation state management.

# %%
def receive_audio_and_playback(connection: VoiceLiveConnection) -> None:
    """
    Receive messages from Voice Live API and handle audio playback.
    
    This function runs in a separate thread and handles:
    1. Receiving WebSocket messages from the API
    2. Processing different event types
    3. Playing back audio responses
    4. Managing conversation state
    
    Args:
        connection: Active VoiceLiveConnection instance
    """
    last_audio_item_id = None
    audio_player = AudioPlayerAsync()
    event_count = 0
    session_id = None

    logger.info("Starting audio playback thread...")
    print("🎧 Audio playback thread started - monitoring events...")
    
    try:
        while not stop_event.is_set():
            # Receive message from API
            raw_event = connection.recv()
            if raw_event is None:
                continue
                
            try:
                event = json.loads(raw_event)
                event_type = event.get("type")
                event_count += 1
                
                # Log every event with timestamp
                timestamp = datetime.now().strftime("%H:%M:%S.%f")[:-3]
                print(f"📨 [{timestamp}] Event #{event_count}: {event_type}")
                logger.info(f"Event #{event_count}: {event_type} - {event}")

                # Handle different event types with detailed logging
                if event_type == "session.created":
                    session = event.get("session", {})
                    session_id = session.get('id', 'unknown')
                    print(f"✅ Session created: {session_id}")
                    print(f"   Instructions: {session.get('instructions', 'Not set')[:100]}...")
                    print(f"   Voice: {session.get('voice', {}).get('name', 'Not set')}")
                    logger.info(f"Session created: {session_id}")

                elif event_type == "session.updated":
                    session = event.get("session", {})
                    print(f"🔄 Session updated")
                    print(f"   Voice: {session.get('voice', {}).get('name', 'Not set')}")
                    print(f"   VAD: {session.get('turn_detection', {}).get('type', 'Not set')}")

                elif event_type == "input_audio_buffer.committed":
                    item_id = event.get("item_id", "unknown")
                    print(f"🎤 Audio buffer committed: {item_id}")

                elif event_type == "input_audio_buffer.speech_started":
                    # User started speaking - stop AI playback
                    print(f"🗣️  Speech started - stopping AI playback")
                    audio_player.stop()

                elif event_type == "input_audio_buffer.speech_stopped":
                    print(f"🤐 Speech stopped - processing...")

                elif event_type == "conversation.item.created":
                    item = event.get("item", {})
                    item_type = item.get("type", "unknown")
                    item_id = item.get("id", "unknown")
                    print(f"📝 Item created: {item_type} ({item_id})")
                    if item_type == "message":
                        role = item.get("role", "unknown")
                        print(f"   Role: {role}")

                elif event_type == "response.created":
                    response = event.get("response", {})
                    response_id = response.get("id", "unknown")
                    print(f"🤖 Response created: {response_id}")

                elif event_type == "response.output_item.added":
                    item = event.get("item", {})
                    item_type = item.get("type", "unknown")
                    item_id = item.get("id", "unknown")
                    print(f"➕ Output item added: {item_type} ({item_id})")

                elif event_type == "response.content_part.added":
                    part = event.get("part", {})
                    part_type = part.get("type", "unknown")
                    print(f"🧩 Content part added: {part_type}")

                elif event_type == "response.audio_transcript.delta":
                    delta = event.get("delta", "")
                    item_id = event.get("item_id", "unknown")
                    print(f"📝 Transcript delta: '{delta}' (item: {item_id})")

                elif event_type == "response.audio.delta":
                    # New audio data from AI response
                    item_id = event.get("item_id", "unknown")
                    delta_length = len(event.get("delta", ""))
                    
                    if item_id != last_audio_item_id:
                        last_audio_item_id = item_id
                        print(f"🎵 New audio item: {item_id}")

                    # Decode and play audio
                    bytes_data = base64.b64decode(event.get("delta", ""))
                    if bytes_data:
                        print(f"🔊 Playing audio chunk: {len(bytes_data)} bytes")
                        logger.debug(f"Audio data length: {len(bytes_data)} bytes")   
                        audio_player.add_data(bytes_data)

                elif event_type == "response.audio.done":
                    item_id = event.get("item_id", "unknown")
                    print(f"✅ Audio complete: {item_id}")

                elif event_type == "response.content_part.done":
                    part = event.get("part", {})
                    part_type = part.get("type", "unknown")
                    print(f"✅ Content part done: {part_type}")

                elif event_type == "response.output_item.done":
                    item = event.get("item", {})
                    item_type = item.get("type", "unknown")
                    item_id = item.get("id", "unknown")
                    print(f"✅ Output item done: {item_type} ({item_id})")

                elif event_type == "response.done":
                    response = event.get("response", {})
                    response_id = response.get("id", "unknown")
                    status = response.get("status", "unknown")
                    print(f"✅ Response complete: {response_id} (status: {status})")

                elif event_type == "rate_limits.updated":
                    limits = event.get("rate_limits", [])
                    print(f"📊 Rate limits updated: {len(limits)} limits")
                    for limit in limits:
                        name = limit.get("name", "unknown")
                        remaining = limit.get("remaining", 0)
                        print(f"   {name}: {remaining} remaining")

                elif event_type == "error":
                    # Handle API errors
                    error_details = event.get("error", {})
                    error_type = error_details.get("type", "Unknown")
                    error_code = error_details.get("code", "Unknown")
                    error_message = error_details.get("message", "No message provided")
                    print(f"❌ ERROR: {error_type} ({error_code})")
                    print(f"   Message: {error_message}")
                    logger.error(f"API Error: {error_type} - {error_code} - {error_message}")
                    raise ValueError(f"API Error: {error_type} ({error_code}) - {error_message}")
                
                else:
                    # Log any unknown event types
                    print(f"❓ Unknown event: {event_type}")
                    logger.warning(f"Unknown event type: {event_type} - {event}")
                    
            except json.JSONDecodeError as e:
                logger.error(f"Failed to parse JSON event: {e}")
                print(f"❌ JSON Parse Error: {e}")
                continue

    except Exception as e:
        logger.error(f"Error in audio playback: {e}")
        print(f"❌ Audio playback error: {e}")
        import traceback
        traceback.print_exc()
    finally:
        audio_player.terminate()
        print(f"✅ Audio playback thread completed ({event_count} events processed)")
        logger.info(f"Audio playback done. Processed {event_count} events.")

print("✅ Enhanced audio output function with comprehensive event logging")
# Out:
# ✅ Enhanced audio output function with comprehensive event logging

# %% [markdown]
# ## **8. Graceful Shutdown Handler**

# %%
def read_keyboard_and_quit() -> None:
    """
    Monitor keyboard input for quit command.
    
    This function runs in a separate thread and waits for the user
    to type 'q' to gracefully shutdown the application.
    """
    print("Press 'q' and Enter to quit the chat.")
    
    while not stop_event.is_set():
        try:
            user_input = input()
            if user_input.strip().lower() == 'q':
                print("Quitting the chat...")
                stop_event.set()
                break
        except EOFError:
            # Handle case where input is interrupted
            break

print("✅ User input function defined")
# Out:
# ✅ User input function defined

# %% [markdown]
# ## **9. Session Configuration**
#
# Production-grade session settings with semantic VAD and audio preprocessing.

# %%
# Session configuration for the Voice Live API
session_config = {
    "type": "session.update",
    "session": {
        # Basic AI behavior
        "instructions": "You are a helpful AI assistant responding in natural, engaging language.",
        
        # Voice Activity Detection (VAD) settings
        "turn_detection": {
            "type": "azure_semantic_vad",
            "threshold": 0.3,  # Sensitivity for detecting speech
            "prefix_padding_ms": 200,  # Keep audio before speech starts
            "silence_duration_ms": 200,  # How long to wait for silence
            "remove_filler_words": False,  # Keep "um", "uh", etc.
            "end_of_utterance_detection": {
                "model": "semantic_detection_v1",
                "threshold": 0.01,  # When to consider speech finished
                "timeout": 2,  # Max time to wait for continuation
            },
        },
        
        # Audio preprocessing
        "input_audio_noise_reduction": {
            "type": "azure_deep_noise_suppression"  # Remove background noise
        },
        "input_audio_echo_cancellation": {
            "type": "server_echo_cancellation"  # Prevent feedback loops
        },
        
        # AI voice settings
        "voice": {
            "name": "en-US-Ava:DragonHDLatestNeural",  # High-quality neural voice
            "type": "azure-standard",
            "temperature": 0.8,  # Controls response creativity/randomness
        },
    },
    "event_id": ""
}

print("✅ Session configuration created")
print(f"   - Voice: {session_config['session']['voice']['name']}")
print(f"   - VAD Type: {session_config['session']['turn_detection']['type']}")
print(f"   - Noise Reduction: {session_config['session']['input_audio_noise_reduction']['type']}")
print(f"   - Echo Cancellation: {session_config['session']['input_audio_echo_cancellation']['type']}")
# Out:
# ✅ Session configuration created
#    - Voice: en-US-Ava:DragonHDLatestNeural
#    - VAD Type: azure_semantic_vad
#    - Noise Reduction: azure_deep_noise_suppression
#    - Echo Cancellation: server_echo_cancellation

# %% [markdown]
# ## **10. Authentication & Client Setup**
#
# Dual authentication strategy: Entra ID (preferred) with API key fallback.

# %%
# Setup logging for this session
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Create logs directory if it doesn't exist
import os
if not os.path.exists('logs'):
    os.makedirs('logs')

# Configure logging
logging.basicConfig(
    filename=f'logs/{timestamp}_voicelive_notebook.log',
    filemode="w",
    level=logging.DEBUG,
    format='%(asctime)s:%(name)s:%(levelname)s:%(message)s'
)

# Setup authentication - prefer token-based auth
credential = DefaultAzureCredential()
scopes = "https://ai.azure.com/.default"

try:
    token = credential.get_token(scopes)
    auth_method = "token"
    print("✅ Using token-based authentication")
except Exception as e:
    print(f"⚠️  Token auth failed: {e}")
    print("🔑 Falling back to API key authentication")
    auth_method = "api_key"

# Create the client
client_kwargs = {
    "azure_endpoint": AZURE_VOICE_LIVE_ENDPOINT,
    "api_version": AZURE_VOICE_LIVE_API_VERSION,
}

if auth_method == "token":
    client_kwargs["token"] = token.token
else:
    client_kwargs["api_key"] = AZURE_VOICE_LIVE_API_KEY

client = AzureVoiceLive(**client_kwargs)

print(f"✅ Azure Voice Live client created successfully")
print(f"   - Authentication: {auth_method}")
print(f"   - Endpoint: {AZURE_VOICE_LIVE_ENDPOINT}")
print(f"   - Model: {AZURE_VOICE_LIVE_MODEL}")
# Out:
# ✅ Using token-based authentication
# ✅ Azure Voice Live client created successfully
#    - Authentication: token
#    - Endpoint: https://poc-ai-agents-voice-resource.cognitiveservices.azure.com/
#    - Model: gpt-4o

# %% [markdown]
# ## **11. Connection Validation**

# %%
# Test connection (optional - uncomment to run)
# This will establish a connection and immediately close it

try:
    print("🔌 Testing connection...")
    test_connection = client.connect(model=AZURE_VOICE_LIVE_MODEL)
    print("✅ Connection test successful!")
    test_connection.close()
    print("🔌 Test connection closed")
except Exception as e:
    print(f"❌ Connection test failed: {e}")

# print("ℹ️  Connection test code ready (uncomment to run)")
# Out:
# 🔌 Testing connection...
# 🔌 Establishing WebSocket connection (ID: 8ac4b62b)...
# ✅ WebSocket connection opened (ID: 8ac4b62b)
# ✅ Connection established successfully (ID: 8ac4b62b)
# ✅ Connection test successful!
# 🔌 Closing WebSocket connection (ID: 8ac4b62b)...
# ✅ WebSocket connection opened (ID: 8ac4b62b)
# ✅ Connection established successfully (ID: 8ac4b62b)
# ✅ Connection test successful!
# 🔌 Closing WebSocket connection (ID: 8ac4b62b)...
# 🔌 WebSocket connection closed (ID: 8ac4b62b)
#    Status: None, Message: None
# ✅ Connection closed (ID: 8ac4b62b, 1 messages processed)
# 🔌 Test connection closed
# 🔌 WebSocket connection closed (ID: 8ac4b62b)
#    Status: None, Message: None
# ✅ Connection closed (ID: 8ac4b62b, 1 messages processed)
# 🔌 Test connection closed

# %% [markdown]
# ## **Development Utilities & Diagnostics**

# %%
# Development and testing utilities

def check_audio_devices():
    """Check available audio input and output devices."""
    print("🎤 Available Audio Input Devices:")
    for i, device in enumerate(sd.query_devices()):
        if device['max_input_channels'] > 0:
            print(f"  {i}: {device['name']} (inputs: {device['max_input_channels']})")
    
    print("\n🔊 Available Audio Output Devices:")
    for i, device in enumerate(sd.query_devices()):
        if device['max_output_channels'] > 0:
            print(f"  {i}: {device['name']} (outputs: {device['max_output_channels']})")
    
    print(f"\n🎛️  Default Input Device: {sd.query_devices(sd.default.device[0])['name']}")
    print(f"🎛️  Default Output Device: {sd.query_devices(sd.default.device[1])['name']}")

def test_microphone(duration=3):
    """Test microphone input for a few seconds."""
    print(f"🎤 Testing microphone for {duration} seconds...")
    print("💬 Please speak into your microphone...")
    
    def callback(indata, frames, time, status):
        volume_norm = np.linalg.norm(indata) * 10
        print(f"📊 Volume level: {'█' * int(volume_norm)}")
    
    with sd.InputStream(callback=callback, channels=1, samplerate=AUDIO_SAMPLE_RATE):
        sd.sleep(duration * 1000)
    
    print("✅ Microphone test complete")

def create_custom_session_config(
    instructions="You are a helpful AI assistant.",
    voice_name="en-US-Ava:DragonHDLatestNeural",
    temperature=0.8,
    vad_threshold=0.3
):
    """Create a custom session configuration."""
    return {
        "type": "session.update",
        "session": {
            "instructions": instructions,
            "turn_detection": {
                "type": "azure_semantic_vad",
                "threshold": vad_threshold,
                "prefix_padding_ms": 200,
                "silence_duration_ms": 200,
                "remove_filler_words": False,
                "end_of_utterance_detection": {
                    "model": "semantic_detection_v1",
                    "threshold": 0.01,
                    "timeout": 2,
                },
            },
            "input_audio_noise_reduction": {
                "type": "azure_deep_noise_suppression"
            },
            "input_audio_echo_cancellation": {
                "type": "server_echo_cancellation"
            },
            "voice": {
                "name": voice_name,
                "type": "azure-standard",
                "temperature": temperature,
            },
        },
        "event_id": ""
    }

def view_logs():
    """View the most recent log file."""
    import glob
    log_files = glob.glob("logs/*.log")
    if log_files:
        latest_log = max(log_files, key=os.path.getctime)
        print(f"📝 Latest log file: {latest_log}")
        with open(latest_log, 'r') as f:
            lines = f.readlines()
            print("📄 Last 20 lines:")
            for line in lines[-20:]:
                print(line.strip())
    else:
        print("📝 No log files found")

print("✅ Development utilities loaded:")
print("  - check_audio_devices(): Check available audio devices")
print("  - test_microphone(duration=3): Test microphone input")
print("  - create_custom_session_config(): Create custom configurations")
print("  - view_logs(): View recent log entries")
# Out:
# ✅ Development utilities loaded:
#   - check_audio_devices(): Check available audio devices
#   - test_microphone(duration=3): Test microphone input
#   - create_custom_session_config(): Create custom configurations
#   - view_logs(): View recent log entries

# %% [markdown]
# ## **Troubleshooting & Best Practices**
#
# ### **Common Issues**
# - **401/403**: Verify Entra ID permissions and endpoint URL
# - **404/409**: Check agent ID and API version
# - **Audio latency**: Optimize buffer sizes and sample rates
# - **Connection hangs**: Implement proper timeout and cleanup
#
# ### **Production Considerations**
# - **Authentication**: Use Entra ID in production, API keys for development
# - **Audio Quality**: 24kHz sample rate with noise suppression enabled
# - **Error Handling**: Implement circuit breakers and retry logic
# - **Monitoring**: Add Application Insights telemetry
# - **Scaling**: Use connection pooling for high-volume scenarios

# %% [markdown]
# ## **Audio Diagnostics**

# %%
# First, let's check your audio devices
print("🔍 Checking audio device configuration...")
check_audio_devices()

print("\n" + "="*60)
print("🎤 Testing microphone for 3 seconds...")
print("Please speak into your microphone!")
test_microphone(duration=3)
# Out:
# 🔍 Checking audio device configuration...
# 🎤 Available Audio Input Devices:
#   0: Microsoft Sound Mapper - Input (inputs: 2)
#   1: Surface Stereo Microphones (Sur (inputs: 2)
#   2: Microphone (Lumina Camera - Raw (inputs: 2)
#   6: Primary Sound Capture Driver (inputs: 2)
#   7: Surface Stereo Microphones (Surface High Definition Audio) (inputs: 2)
#   8: Microphone (Lumina Camera - Raw) (inputs: 2)
#   14: Surface Stereo Microphones (Surface High Definition Audio) (inputs: 2)
#   15: Microphone (Lumina Camera - Raw) (inputs: 2)
#   17: Microphone (Microsoft Surface Thunderbolt(TM) 4 Dock Audio) (inputs: 1)
#   20: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Shiva’s AirPods Pro #2)) (inputs: 1)
#   22: Microphone (Dell USB Audio) (inputs: 2)
#   24: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Shiva’s AirPods Pro #2 - Find My)) (inputs: 1)
#   27: PC Speaker (Realtek HD Audio 2nd output with SST) (inputs: 2)
#   30: PC Speaker (Realtek HD Audio output with SST) (inputs: 2)
#   31: Microphone Array (Realtek HD Audio Mic input) (inputs: 2)
#   32: Headset Microphone (Headset Microphone) (inputs: 2)
#   34: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Pablo’s AirPods #3)) (inputs: 1)
#   35: Input () (inputs: 2)
#   37: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Pablo’s AirPods #4)) (inputs: 1)
#   40: Input (@System32\drivers\bthhfenum.sys,#4;%1 Hands-Free HF Audio%0
# ;(iPhone de Pablo)) (inputs: 1)
#   42: Microphone (Lumina Camera - Raw) (inputs: 2)
#   45: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Pablo’s AirPods Pro - Find My)) (inputs: 1)
#
# 🔊 Available Audio Output Devices:
#   3: Microsoft Sound Mapper - Output (outputs: 2)
#   4: Surface Omnisonic Speakers (Sur (outputs: 2)
#   5: Speakers (Dell USB Audio) (outputs: 6)
#   9: Primary Sound Driver (outputs: 2)
#   10: Surface Omnisonic Speakers (Surface High Definition Audio) (outputs: 2)
#   11: Speakers (Dell USB Audio) (outputs: 6)
#   12: Speakers (Dell USB Audio) (outputs: 2)
#   13: Surface Omnisonic Speakers (Surface High Definition Audio) (outputs: 2)
#   16: Headphones () (outputs: 2)
#   18: Output (Microsoft Surface Thunderbolt(TM) 4 Dock Audio) (outputs: 2)
#   19: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Shiva’s AirPods Pro #2)) (outputs: 1)
#   21: Speakers (Dell USB Audio) (outputs: 6)
#   23: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Shiva’s AirPods Pro #2 - Find My)) (outputs: 1)
#   25: Headphones 1 (Realtek HD Audio 2nd output with SST) (outputs: 2)
#   26: Headphones 2 (Realtek HD Audio 2nd output with SST) (outputs: 2)
#   28: Speakers 1 (Realtek HD Audio output with SST) (outputs: 2)
#   29: Speakers 2 (Realtek HD Audio output with SST) (outputs: 2)
#   33: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Pablo’s AirPods #3)) (outputs: 1)
#   36: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Pablo’s AirPods #4)) (outputs: 1)
#   38: Headphones () (outputs: 2)
#   39: Output (@System32\drivers\bthhfenum.sys,#4;%1 Hands-Free HF Audio%0
# ;(iPhone de Pablo)) (outputs: 1)
#   41: Headphones () (outputs: 2)
#   43: Headphones () (outputs: 2)
#   44: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Pablo’s AirPods Pro - Find My)) (outputs: 1)
#   46: Headphones () (outputs: 2)
#
# 🎛️  Default Input Device: Surface Stereo Microphones (Sur
# 🎛️  Default Output Device: Surface Omnisonic Speakers (Sur
#
# ============================================================
# 🎤 Testing microphone for 3 seconds...
# Please speak into your microphone!
# 🎤 Testing microphone for 3 seconds...
# 💬 Please speak into your microphone...
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level: █
# 📊 Volume level: ██
# 📊 Volume level: ██
# 📊 Volume level: ███
# 📊 Volume level: ███
# 📊 Volume level: █████
# 📊 Volume level: █████
# 📊 Volume level: ████
# 📊 Volume level:
# 📊 Volume level: █
# 📊 Volume level: ██
# 📊 Volume level: ██
# 📊 Volume level: ███
# 📊 Volume level: ███
# 📊 Volume level: █████
# 📊 Volume level: █████
# 📊 Volume level: ████
# 📊 Volume level: ███
# 📊 Volume level: ███
# ✅ Microphone test complete
# 📊 Volume level: ███
# 📊 Volume level: ███
# ✅ Microphone test complete

# %%
def run_voice_chat_debug():
    """
    Enhanced voice chat function with better debugging and error handling.
    """
    global stop_event
    connection = None  # Initialize connection variable
    
    try:
        # Reset the stop event for a fresh start
        stop_event.clear()
        
        print("🚀 Starting Voice Live chat application (DEBUG MODE)...")
        
        # 1. Connect to the API
        connection = client.connect(model=AZURE_VOICE_LIVE_MODEL)
        print("✅ Connected to Voice Live API")
        
        # 2. Send session configuration
        connection.send(json.dumps(session_config))
        print("✅ Session configuration sent")
        print(f"   Instructions: {session_config['session']['instructions'][:50]}...")
        print(f"   Voice: {session_config['session']['voice']['name']}")
        
        # 3. Wait a moment to receive session.created event
        print("⏳ Waiting for session creation...")
        time.sleep(2)
        
        # Check for any immediate messages
        for i in range(5):
            msg = connection.recv()
            if msg:
                try:
                    event = json.loads(msg)
                    print(f"📨 Received: {event.get('type', 'unknown')}")
                    if event.get('type') == 'session.created':
                        print(f"   Session ID: {event.get('session', {}).get('id', 'unknown')}")
                    elif event.get('type') == 'error':
                        print(f"❌ Error: {event.get('error', {})}")
                except:
                    print(f"📨 Raw message: {msg[:100]}...")
            else:
                break
        
        # 4. Create and start threads with better error handling
        print("🧵 Starting threads...")
        
        def safe_listen_and_send_audio(connection):
            try:
                listen_and_send_audio(connection)
            except Exception as e:
                print(f"❌ Audio input error: {e}")
                stop_event.set()
        
        def safe_receive_audio_and_playback(connection):
            try:
                receive_audio_and_playback(connection)
            except Exception as e:
                print(f"❌ Audio output error: {e}")
                stop_event.set()
        
        send_thread = threading.Thread(
            target=safe_listen_and_send_audio, 
            args=(connection,),
            name="AudioInput"
        )
        receive_thread = threading.Thread(
            target=safe_receive_audio_and_playback, 
            args=(connection,),
            name="AudioOutput"
        )
        
        # Start audio threads
        send_thread.start()
        receive_thread.start()
        
        print("🎙️  Voice chat is now active!")
        print("💬 You can start speaking...")
        print("📊 Monitoring audio threads...")
        
        # Monitor threads instead of waiting for keyboard input
        start_time = time.time()
        max_runtime = 60  # Maximum runtime in seconds before auto-shutdown
        
        while not stop_event.is_set():
            # Check if threads are still alive
            if not send_thread.is_alive():
                print("⚠️  Audio input thread died")
                stop_event.set()
                break
            if not receive_thread.is_alive():
                print("⚠️  Audio output thread died")
                stop_event.set()
                break
            
            # Auto-shutdown after max runtime to prevent hanging
            if time.time() - start_time > max_runtime:
                print(f"⏰ Auto-shutdown after {max_runtime} seconds")
                stop_event.set()
                break
            
            # Print status every 10 seconds
            if (time.time() - start_time) % 10 < 1:
                elapsed = int(time.time() - start_time)
                remaining = max_runtime - elapsed
                print(f"📊 Running {elapsed}s... Threads alive. {remaining}s remaining. Speak into your microphone!")
            
            time.sleep(1)
        
    except Exception as e:
        print(f"❌ Error in voice chat: {e}")
        import traceback
        traceback.print_exc()
        stop_event.set()
    
    finally:
        # ALWAYS ensure cleanup happens
        print("🛑 Shutting down...")
        stop_event.set()
        
        # Wait for threads to finish (with timeout)
        if 'send_thread' in locals() and send_thread.is_alive():
            send_thread.join(timeout=3)
            if send_thread.is_alive():
                print("⚠️  Audio input thread did not stop gracefully")
        
        if 'receive_thread' in locals() and receive_thread.is_alive():
            receive_thread.join(timeout=3)
            if receive_thread.is_alive():
                print("⚠️  Audio output thread did not stop gracefully")
        
        # Close connection - this is the critical fix
        if connection is not None:
            try:
                connection.close()
                print("✅ WebSocket connection closed properly")
            except Exception as e:
                print(f"⚠️  Error closing connection: {e}")
        else:
            print("ℹ️  No connection to close")
        
        print("✅ Voice chat cleanup completed")

print("✅ Debug voice chat function created with proper connection cleanup")
# Out:
# ✅ Debug voice chat function created with proper connection cleanup

# %%
# Run the debug version of voice chat
# This will show more detailed information about what's happening

# First check if we can see logs
print("📝 Checking recent logs:")
view_logs()

print("\n" + "="*60)
print("🚀 Starting DEBUG voice chat...")
print("This version will run for a while and show more status information")
print("Watch for error messages and connection status")

# Uncomment the line below to run debug version:
run_voice_chat_debug()

print("💡 Uncomment the line above to run the debug version")
# Out:
# 📝 Checking recent logs:
# 📝 Latest log file: logs\2025-09-02_00-06-48_voicelive_notebook.log
# 📄 Last 20 lines:
# File "c:\Users\pablosal\AppData\Local\anaconda3\envs\audioagent\Lib\site-packages\azure\identity\_credentials\shared_cache.py", line 152, in get_token
# token_info = self._get_token_base(*scopes, options=options, base_method_name="get_token", **kwargs)
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# File "c:\Users\pablosal\AppData\Local\anaconda3\envs\audioagent\Lib\site-packages\azure\identity\_credentials\shared_cache.py", line 186, in _get_token_base
# account = self._get_account(self._username, self._tenant_id, is_cae=is_cae)
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# File "c:\Users\pablosal\AppData\Local\anaconda3\envs\audioagent\Lib\site-packages\azure\identity\_internal\decorators.py", line 67, in wrapper
# return fn(*args, **kwargs)
# ^^^^^^^^^^^^^^^^^^^
# File "c:\Users\pablosal\AppData\Local\anaconda3\envs\audioagent\Lib\site-packages\azure\identity\_internal\shared_token_cache.py", line 209, in _get_account
# raise CredentialUnavailableError(message=NO_ACCOUNTS)
# azure.identity._exceptions.CredentialUnavailableError: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 2025-09-02 00:06:51,415:azure.identity._internal.decorators:DEBUG:AzureCliCredential.get_token succeeded
# 2025-09-02 00:06:51,415:azure.identity._internal.decorators:DEBUG:[Authenticated account] Client ID: 04b07795-8ddb-461a-bbee-02f9e1bf7b46. Tenant ID: 16b3c013-d300-468d-ac64-7eda0820b6d3. User Principal Name: unavailableUpn. Object ID (user): 9d5a93c3-a26f-4a69-b0a1-fc8b5c37b216
# 2025-09-02 00:06:51,415:azure.identity._credentials.chained:INFO:DefaultAzureCredential acquired a token from AzureCliCredential
# 2025-09-02 00:06:51,729:websocket:INFO:Websocket connected
# 2025-09-02 00:06:51,734:__main__:INFO:Connection 8ac4b62b: WebSocket opened
# 2025-09-02 00:06:51,736:__main__:DEBUG:Connection 8ac4b62b: Message #1 queued
# 2025-09-02 00:06:51,742:__main__:INFO:Connection 8ac4b62b: Closing connection
# 2025-09-02 00:06:52,781:__main__:INFO:Connection 8ac4b62b: WebSocket closed - None: None
#
# ============================================================
# 🚀 Starting DEBUG voice chat...
# This version will run for a while and show more status information
# Watch for error messages and connection status
# 🚀 Starting Voice Live chat application (DEBUG MODE)...
# 🔌 Establishing WebSocket connection (ID: e401a950)...
# ✅ WebSocket connection opened (ID: e401a950)
# ✅ Connection established successfully (ID: e401a950)
# ✅ Connected to Voice Live API
# ✅ Session configuration sent
#    Instructions: You are a helpful AI assistant responding in natur...
#    Voice: en-US-Ava:DragonHDLatestNeural
# ⏳ Waiting for session creation...
# ✅ WebSocket connection opened (ID: e401a950)
# ✅ Connection established successfully (ID: e401a950)
# ✅ Connected to Voice Live API
# ✅ Session configuration sent
#    Instructions: You are a helpful AI assistant responding in natur...
#    Voice: en-US-Ava:DragonHDLatestNeural
# ⏳ Waiting for session creation...
# 📨 Received: session.created
#    Session ID: sess_3jlvKi87kdSK3NGnFFyZ3M
# 📨 Received: session.updated
# 📨 Received: session.created
#    Session ID: sess_3jlvKi87kdSK3NGnFFyZ3M
# 📨 Received: session.updated
# 🧵 Starting threads...
# 🎙️  Voice chat is now active!
# 💬 You can start speaking...
# 📊 Monitoring audio threads...
# 📊 Running 0s... Threads alive. 60s remaining. Speak into your microphone!
# 🧵 Starting threads...
# 🎙️  Voice chat is now active!
# 💬 You can start speaking...
# 📊 Monitoring audio threads...
# 📊 Running 0s... Threads alive. 60s remaining. Speak into your microphone!
# 🎧 Audio playback thread started - monitoring events...
# 🎧 Audio playback thread started - monitoring events...
# 📨 [00:07:15.996] Event #1: input_audio_buffer.speech_started
# 🗣️  Speech started - stopping AI playback
# 📨 [00:07:15.996] Event #1: input_audio_buffer.speech_started
# 🗣️  Speech started - stopping AI playback
# 📨 [00:07:17.114] Event #2: input_audio_buffer.speech_stopped
# 🤐 Speech stopped - processing...
# 📨 [00:07:17.115] Event #3: input_audio_buffer.committed
# 🎤 Audio buffer committed: item_5R5gLFbDhz3bTlQTPJgLGB
# 📨 [00:07:17.114] Event #2: input_audio_buffer.speech_stopped
# 🤐 Speech stopped - processing...
# 📨 [00:07:17.115] Event #3: input_audio_buffer.committed
# 🎤 Audio buffer committed: item_5R5gLFbDhz3bTlQTPJgLGB
# 📨 [00:07:17.363] Event #4: conversation.item.input_audio_transcription.completed
# ❓ Unknown event: conversation.item.input_audio_transcription.completed
# 📨 [00:07:17.365] Event #5: conversation.item.created
# 📝 Item created: message (item_5R5gLFbDhz3bTlQTPJgLGB)
#    Role: user
# 📨 [00:07:17.365] Event #6: response.created
# 🤖 Response created: resp_3mvYtwSr4IiEtSynxkjJP7
# 📨 [00:07:17.363] Event #4: conversation.item.input_audio_transcription.completed
# ❓ Unknown event: conversation.item.input_audio_transcription.completed
# 📨 [00:07:17.365] Event #5: conversation.item.created
# 📝 Item created: message (item_5R5gLFbDhz3bTlQTPJgLGB)
#    Role: user
# 📨 [00:07:17.365] Event #6: response.created
# 🤖 Response created: resp_3mvYtwSr4IiEtSynxkjJP7
# 📨 [00:07:17.664] Event #7: response.output_item.added
# ➕ Output item added: message (item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.665] Event #8: conversation.item.created
# 📝 Item created: message (item_3BLs21Yi5tnWkEKToXjnFK)
#    Role: assistant
# 📨 [00:07:17.666] Event #9: response.content_part.added
# 🧩 Content part added: audio
# 📨 [00:07:17.667] Event #10: response.audio_transcript.delta
# 📝 Transcript delta: 'Hello' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.667] Event #11: response.audio_transcript.delta
# 📝 Transcript delta: '!' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.671] Event #12: response.audio_transcript.delta
# 📝 Transcript delta: ' I'm' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.693] Event #13: response.audio_transcript.delta
# 📝 Transcript delta: ' just' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.823] Event #14: response.audio_transcript.delta
# 📝 Transcript delta: ' a' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.823] Event #15: response.audio_transcript.delta
# 📝 Transcript delta: ' virtual' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.824] Event #16: response.audio_transcript.delta
# 📝 Transcript delta: ' assistant' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.825] Event #17: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.826] Event #18: response.audio_transcript.delta
# 📝 Transcript delta: ' so' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.826] Event #19: response.audio_transcript.delta
# 📝 Transcript delta: ' I' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.826] Event #20: response.audio_transcript.delta
# 📝 Transcript delta: ' don't' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.829] Event #21: response.audio_transcript.delta
# 📝 Transcript delta: ' really' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.830] Event #22: response.audio_transcript.delta
# 📝 Transcript delta: ' have' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.830] Event #23: response.audio_transcript.delta
# 📝 Transcript delta: ' feelings' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.830] Event #24: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.831] Event #25: response.audio_transcript.delta
# 📝 Transcript delta: ' but' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.842] Event #26: response.audio_transcript.delta
# 📝 Transcript delta: ' I'm' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.851] Event #27: response.audio_transcript.delta
# 📝 Transcript delta: ' here' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.863] Event #28: response.audio_transcript.delta
# 📝 Transcript delta: ' and' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.876] Event #29: response.audio_transcript.delta
# 📨 [00:07:17.664] Event #7: response.output_item.added
# ➕ Output item added: message (item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.665] Event #8: conversation.item.created
# 📝 Item created: message (item_3BLs21Yi5tnWkEKToXjnFK)
#    Role: assistant
# 📨 [00:07:17.666] Event #9: response.content_part.added
# 🧩 Content part added: audio
# 📨 [00:07:17.667] Event #10: response.audio_transcript.delta
# 📝 Transcript delta: 'Hello' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.667] Event #11: response.audio_transcript.delta
# 📝 Transcript delta: '!' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.671] Event #12: response.audio_transcript.delta
# 📝 Transcript delta: ' I'm' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.693] Event #13: response.audio_transcript.delta
# 📝 Transcript delta: ' just' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.823] Event #14: response.audio_transcript.delta
# 📝 Transcript delta: ' a' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.823] Event #15: response.audio_transcript.delta
# 📝 Transcript delta: ' virtual' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.824] Event #16: response.audio_transcript.delta
# 📝 Transcript delta: ' assistant' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.825] Event #17: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.826] Event #18: response.audio_transcript.delta
# 📝 Transcript delta: ' so' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.826] Event #19: response.audio_transcript.delta
# 📝 Transcript delta: ' I' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.826] Event #20: response.audio_transcript.delta
# 📝 Transcript delta: ' don't' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.829] Event #21: response.audio_transcript.delta
# 📝 Transcript delta: ' really' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.830] Event #22: response.audio_transcript.delta
# 📝 Transcript delta: ' have' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.830] Event #23: response.audio_transcript.delta
# 📝 Transcript delta: ' feelings' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.830] Event #24: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.831] Event #25: response.audio_transcript.delta
# 📝 Transcript delta: ' but' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.842] Event #26: response.audio_transcript.delta
# 📝 Transcript delta: ' I'm' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.851] Event #27: response.audio_transcript.delta
# 📝 Transcript delta: ' here' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.863] Event #28: response.audio_transcript.delta
# 📝 Transcript delta: ' and' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.876] Event #29: response.audio_transcript.delta
# 📝 Transcript delta: ' ready' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.881] Event #30: response.audio.delta
# 🎵 New audio item: item_3BLs21Yi5tnWkEKToXjnFK
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:17.887] Event #31: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:17.888] Event #32: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:17.891] Event #33: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.894] Event #34: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:17.896] Event #35: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:17.899] Event #36: response.audio_transcript.delta
# 📝 Transcript delta: ' help' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.910] Event #37: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:17.911] Event #38: response.audio_transcript.delta
# 📝 Transcript delta: ' with' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.912] Event #39: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:17.924] Event #40: response.audio_transcript.delta
# 📝 Transcript delta: ' whatever' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.930] Event #41: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:17.931] Event #42: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:17.934] Event #43: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:17.936] Event #44: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.941] Event #45: response.audio_transcript.delta
# 📝 Transcript delta: ' need' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.953] Event #46: response.audio_transcript.delta
# 📝 Transcript delta: '.' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.968] Event #47: response.audio_transcript.delta
# 📝 Transcript delta: ' How' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.975] Event #48: response.audio_transcript.delta
# 📝 Transcript delta: ' about' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.986] Event #49: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.999] Event #50: response.audio_transcript.delta
# 📝 Transcript delta: '—' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.010] Event #51: response.audio_transcript.delta
# 📝 Transcript delta: 'how' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.020] Event #52: response.audio_transcript.delta
# 📝 Transcript delta: ' are' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.037] Event #53: response.audio_transcript.delta
# 📝 Transcript delta: ' *' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.041] Event #54: response.audio_transcript.delta
# 📝 Transcript delta: 'you' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.057] Event #55: response.audio_transcript.delta
# 📝 Transcript delta: '*' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.063] Event #56: response.audio_transcript.delta
# 📝 Transcript delta: ' doing' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.070] Event #57: response.audio_transcript.delta
# 📝 Transcript delta: ' today' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.080] Event #58: response.audio_transcript.delta
# 📝 Transcript delta: '?' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.087] Event #59: response.audio_transcript.delta
# 📝 Transcript delta: ' 😊' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📝 Transcript delta: ' ready' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.881] Event #30: response.audio.delta
# 🎵 New audio item: item_3BLs21Yi5tnWkEKToXjnFK
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:17.887] Event #31: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:17.888] Event #32: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:17.891] Event #33: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.894] Event #34: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:17.896] Event #35: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:17.899] Event #36: response.audio_transcript.delta
# 📝 Transcript delta: ' help' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.910] Event #37: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:17.911] Event #38: response.audio_transcript.delta
# 📝 Transcript delta: ' with' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.912] Event #39: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:17.924] Event #40: response.audio_transcript.delta
# 📝 Transcript delta: ' whatever' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.930] Event #41: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:17.931] Event #42: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:17.934] Event #43: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:17.936] Event #44: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.941] Event #45: response.audio_transcript.delta
# 📝 Transcript delta: ' need' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.953] Event #46: response.audio_transcript.delta
# 📝 Transcript delta: '.' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.968] Event #47: response.audio_transcript.delta
# 📝 Transcript delta: ' How' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.975] Event #48: response.audio_transcript.delta
# 📝 Transcript delta: ' about' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.986] Event #49: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:17.999] Event #50: response.audio_transcript.delta
# 📝 Transcript delta: '—' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.010] Event #51: response.audio_transcript.delta
# 📝 Transcript delta: 'how' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.020] Event #52: response.audio_transcript.delta
# 📝 Transcript delta: ' are' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.037] Event #53: response.audio_transcript.delta
# 📝 Transcript delta: ' *' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.041] Event #54: response.audio_transcript.delta
# 📝 Transcript delta: 'you' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.057] Event #55: response.audio_transcript.delta
# 📝 Transcript delta: '*' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.063] Event #56: response.audio_transcript.delta
# 📝 Transcript delta: ' doing' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.070] Event #57: response.audio_transcript.delta
# 📝 Transcript delta: ' today' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.080] Event #58: response.audio_transcript.delta
# 📝 Transcript delta: '?' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.087] Event #59: response.audio_transcript.delta
# 📝 Transcript delta: ' 😊' (item: item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:18.114] Event #60: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.118] Event #61: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.121] Event #62: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:18.137] Event #63: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.139] Event #64: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:18.143] Event #65: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.145] Event #66: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:18.171] Event #67: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.171] Event #68: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:18.174] Event #69: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.174] Event #70: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:18.198] Event #71: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.201] Event #72: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:18.222] Event #73: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.223] Event #74: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:18.249] Event #75: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.251] Event #76: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:18.268] Event #77: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.268] Event #78: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:18.298] Event #79: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.300] Event #80: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.300] Event #81: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:07:18.114] Event #60: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.118] Event #61: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.121] Event #62: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:18.137] Event #63: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.139] Event #64: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:18.143] Event #65: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.145] Event #66: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:18.171] Event #67: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.171] Event #68: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:18.174] Event #69: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.174] Event #70: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:18.198] Event #71: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.201] Event #72: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:18.222] Event #73: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.223] Event #74: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:18.249] Event #75: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.251] Event #76: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:18.268] Event #77: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.268] Event #78: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:18.298] Event #79: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.300] Event #80: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.300] Event #81: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:07:18.327] Event #82: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.331] Event #83: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.332] Event #84: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:07:18.367] Event #85: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.371] Event #86: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.372] Event #87: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:18.401] Event #88: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.403] Event #89: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.405] Event #90: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:18.445] Event #91: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.449] Event #92: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.450] Event #93: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.452] Event #94: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:07:18.488] Event #95: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.491] Event #96: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.492] Event #97: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.495] Event #98: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:07:18.539] Event #99: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.540] Event #100: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.327] Event #82: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.331] Event #83: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.332] Event #84: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:07:18.367] Event #85: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.371] Event #86: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.372] Event #87: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:18.401] Event #88: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.403] Event #89: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.405] Event #90: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:18.445] Event #91: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.449] Event #92: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.450] Event #93: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.452] Event #94: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:07:18.488] Event #95: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.491] Event #96: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.492] Event #97: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.495] Event #98: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:07:18.539] Event #99: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.540] Event #100: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.544] Event #101: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.547] Event #102: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.547] Event #103: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:07:18.591] Event #104: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.596] Event #105: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.597] Event #106: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.600] Event #107: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.601] Event #108: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:07:18.647] Event #109: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.650] Event #110: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.655] Event #111: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.655] Event #112: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.656] Event #113: response.audio.delta
# 🔊 Playing audio chunk: 2822 bytes
# 📨 [00:07:18.715] Event #114: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.716] Event #115: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.720] Event #116: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.722] Event #117: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.723] Event #118: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.723] Event #119: response.audio.delta
# 🔊 Playing audio chunk: 1126 bytes
# 📨 [00:07:18.544] Event #101: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.547] Event #102: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.547] Event #103: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:07:18.591] Event #104: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.596] Event #105: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.597] Event #106: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.600] Event #107: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.601] Event #108: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:07:18.647] Event #109: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.650] Event #110: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.655] Event #111: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.655] Event #112: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.656] Event #113: response.audio.delta
# 🔊 Playing audio chunk: 2822 bytes
# 📨 [00:07:18.715] Event #114: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.716] Event #115: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.720] Event #116: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.722] Event #117: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.723] Event #118: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.723] Event #119: response.audio.delta
# 🔊 Playing audio chunk: 1126 bytes
# 📨 [00:07:18.783] Event #120: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.790] Event #121: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.791] Event #122: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.791] Event #123: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.796] Event #124: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.799] Event #125: response.audio.delta
# 🔊 Playing audio chunk: 3526 bytes
# 📨 [00:07:18.866] Event #126: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.870] Event #127: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.874] Event #128: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.874] Event #129: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.878] Event #130: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.883] Event #131: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.884] Event #132: response.audio.delta
# 🔊 Playing audio chunk: 1830 bytes
# 📨 [00:07:18.950] Event #133: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.952] Event #134: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.954] Event #135: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.956] Event #136: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.958] Event #137: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.962] Event #138: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.965] Event #139: response.audio.delta
# 🔊 Playing audio chunk: 1986 bytes
# 📨 [00:07:18.965] Event #140: response.audio.delta
# 🔊 Playing audio chunk: 2244 bytes
# 📨 [00:07:18.978] Event #141: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.981] Event #142: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.983] Event #143: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.984] Event #144: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.986] Event #145: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:07:18.783] Event #120: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.790] Event #121: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.791] Event #122: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.791] Event #123: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.796] Event #124: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.799] Event #125: response.audio.delta
# 🔊 Playing audio chunk: 3526 bytes
# 📨 [00:07:18.866] Event #126: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.870] Event #127: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.874] Event #128: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.874] Event #129: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.878] Event #130: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.883] Event #131: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.884] Event #132: response.audio.delta
# 🔊 Playing audio chunk: 1830 bytes
# 📨 [00:07:18.950] Event #133: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.952] Event #134: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.954] Event #135: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.956] Event #136: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.958] Event #137: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.962] Event #138: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.965] Event #139: response.audio.delta
# 🔊 Playing audio chunk: 1986 bytes
# 📨 [00:07:18.965] Event #140: response.audio.delta
# 🔊 Playing audio chunk: 2244 bytes
# 📨 [00:07:18.978] Event #141: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:18.981] Event #142: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.983] Event #143: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.984] Event #144: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:18.986] Event #145: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:07:19.093] Event #146: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.098] Event #147: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:19.098] Event #148: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:19.107] Event #149: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.107] Event #150: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:19.123] Event #151: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.133] Event #152: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:19.141] Event #153: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.167] Event #154: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:19.172] Event #155: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.200] Event #156: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:19.206] Event #157: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.233] Event #158: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:19.266] Event #159: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.283] Event #160: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:19.304] Event #161: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.093] Event #146: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.098] Event #147: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:19.098] Event #148: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:19.107] Event #149: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.107] Event #150: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:19.123] Event #151: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.133] Event #152: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:19.141] Event #153: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.167] Event #154: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:19.172] Event #155: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.200] Event #156: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:19.206] Event #157: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.233] Event #158: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:19.266] Event #159: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.283] Event #160: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:19.304] Event #161: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.334] Event #162: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:19.355] Event #163: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.385] Event #164: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:19.405] Event #165: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.433] Event #166: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:19.459] Event #167: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:07:19.470] Event #168: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.516] Event #169: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:19.526] Event #170: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:07:19.537] Event #171: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.334] Event #162: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:19.355] Event #163: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.385] Event #164: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:19.405] Event #165: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.433] Event #166: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:19.459] Event #167: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:07:19.470] Event #168: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.516] Event #169: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:19.526] Event #170: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:07:19.537] Event #171: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:19.569] Event #172: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:19.594] Event #173: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:19.622] Event #174: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:07:19.637] Event #175: response.audio.done
# ✅ Audio complete: item_3BLs21Yi5tnWkEKToXjnFK
# 📨 [00:07:19.637] Event #176: response.audio_transcript.done
# ❓ Unknown event: response.audio_transcript.done
# 📨 [00:07:19.638] Event #177: response.content_part.done
# ✅ Content part done: audio
# 📨 [00:07:19.639] Event #178: response.output_item.done
# ✅ Output item done: message (item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:19.639] Event #179: response.done
# ✅ Response complete: resp_3mvYtwSr4IiEtSynxkjJP7 (status: completed)
# 📨 [00:07:19.569] Event #172: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:19.594] Event #173: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:19.622] Event #174: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:07:19.637] Event #175: response.audio.done
# ✅ Audio complete: item_3BLs21Yi5tnWkEKToXjnFK
# 📨 [00:07:19.637] Event #176: response.audio_transcript.done
# ❓ Unknown event: response.audio_transcript.done
# 📨 [00:07:19.638] Event #177: response.content_part.done
# ✅ Content part done: audio
# 📨 [00:07:19.639] Event #178: response.output_item.done
# ✅ Output item done: message (item_3BLs21Yi5tnWkEKToXjnFK)
# 📨 [00:07:19.639] Event #179: response.done
# ✅ Response complete: resp_3mvYtwSr4IiEtSynxkjJP7 (status: completed)
# 📊 Running 10s... Threads alive. 50s remaining. Speak into your microphone!
# 📊 Running 10s... Threads alive. 50s remaining. Speak into your microphone!
# 📨 [00:07:31.638] Event #180: input_audio_buffer.speech_started
# 🗣️  Speech started - stopping AI playback
# 📨 [00:07:31.638] Event #180: input_audio_buffer.speech_started
# 🗣️  Speech started - stopping AI playback
# 📊 Running 20s... Threads alive. 40s remaining. Speak into your microphone!
# 📊 Running 20s... Threads alive. 40s remaining. Speak into your microphone!
# 📨 [00:07:32.857] Event #181: input_audio_buffer.speech_stopped
# 🤐 Speech stopped - processing...
# 📨 [00:07:32.857] Event #182: input_audio_buffer.committed
# 🎤 Audio buffer committed: item_6aD0B8gDXb7zXUywFg1XHz
# 📨 [00:07:32.857] Event #181: input_audio_buffer.speech_stopped
# 🤐 Speech stopped - processing...
# 📨 [00:07:32.857] Event #182: input_audio_buffer.committed
# 🎤 Audio buffer committed: item_6aD0B8gDXb7zXUywFg1XHz
# 📨 [00:07:33.098] Event #183: conversation.item.input_audio_transcription.completed
# ❓ Unknown event: conversation.item.input_audio_transcription.completed
# 📨 [00:07:33.100] Event #184: conversation.item.created
# 📝 Item created: message (item_6aD0B8gDXb7zXUywFg1XHz)
#    Role: user
# 📨 [00:07:33.100] Event #185: response.created
# 🤖 Response created: resp_4aINlVi5DLrus2F0ZUjM3v
# 📨 [00:07:33.263] Event #186: response.output_item.added
# ➕ Output item added: message (item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.263] Event #187: conversation.item.created
# 📝 Item created: message (item_4ij2qIQdNxtgc29ze1FYsH)
#    Role: assistant
# 📨 [00:07:33.264] Event #188: response.content_part.added
# 🧩 Content part added: audio
# 📨 [00:07:33.264] Event #189: response.audio_transcript.delta
# 📝 Transcript delta: 'Great' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.264] Event #190: response.audio_transcript.delta
# 📝 Transcript delta: ' question' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.271] Event #191: response.audio_transcript.delta
# 📝 Transcript delta: '!' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.283] Event #192: response.audio_transcript.delta
# 📝 Transcript delta: ' I' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.098] Event #183: conversation.item.input_audio_transcription.completed
# ❓ Unknown event: conversation.item.input_audio_transcription.completed
# 📨 [00:07:33.100] Event #184: conversation.item.created
# 📝 Item created: message (item_6aD0B8gDXb7zXUywFg1XHz)
#    Role: user
# 📨 [00:07:33.100] Event #185: response.created
# 🤖 Response created: resp_4aINlVi5DLrus2F0ZUjM3v
# 📨 [00:07:33.263] Event #186: response.output_item.added
# ➕ Output item added: message (item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.263] Event #187: conversation.item.created
# 📝 Item created: message (item_4ij2qIQdNxtgc29ze1FYsH)
#    Role: assistant
# 📨 [00:07:33.264] Event #188: response.content_part.added
# 🧩 Content part added: audio
# 📨 [00:07:33.264] Event #189: response.audio_transcript.delta
# 📝 Transcript delta: 'Great' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.264] Event #190: response.audio_transcript.delta
# 📝 Transcript delta: ' question' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.271] Event #191: response.audio_transcript.delta
# 📝 Transcript delta: '!' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.283] Event #192: response.audio_transcript.delta
# 📝 Transcript delta: ' I' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.305] Event #193: response.audio_transcript.delta
# 📝 Transcript delta: '’m' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.305] Event #194: response.audio_transcript.delta
# 📝 Transcript delta: ' here' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.315] Event #195: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.324] Event #196: response.audio_transcript.delta
# 📝 Transcript delta: ' make' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.331] Event #197: response.audio_transcript.delta
# 📝 Transcript delta: ' your' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.344] Event #198: response.audio_transcript.delta
# 📝 Transcript delta: ' life' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.359] Event #199: response.audio_transcript.delta
# 📝 Transcript delta: ' a' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.365] Event #200: response.audio_transcript.delta
# 📝 Transcript delta: ' little' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.376] Event #201: response.audio_transcript.delta
# 📝 Transcript delta: ' easier' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.394] Event #202: response.audio_transcript.delta
# 📝 Transcript delta: '.' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.395] Event #203: response.audio_transcript.delta
# 📝 Transcript delta: ' Here' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.411] Event #204: response.audio_transcript.delta
# 📝 Transcript delta: ' are' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.417] Event #205: response.audio_transcript.delta
# 📝 Transcript delta: ' some' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.427] Event #206: response.audio_transcript.delta
# 📝 Transcript delta: ' ways' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.441] Event #207: response.audio_transcript.delta
# 📝 Transcript delta: ' I' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.447] Event #208: response.audio_transcript.delta
# 📝 Transcript delta: ' can' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.459] Event #209: response.audio_transcript.delta
# 📝 Transcript delta: ' help' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.470] Event #210: response.audio_transcript.delta
# 📝 Transcript delta: ':
#
# ' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.481] Event #211: response.audio_transcript.delta
# 📝 Transcript delta: '-' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.490] Event #212: response.audio_transcript.delta
# 📝 Transcript delta: ' **' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.502] Event #213: response.audio.delta
# 🎵 New audio item: item_4ij2qIQdNxtgc29ze1FYsH
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:33.505] Event #214: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:33.506] Event #215: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:33.506] Event #216: response.audio_transcript.delta
# 📝 Transcript delta: 'Answer' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.512] Event #217: response.audio_transcript.delta
# 📝 Transcript delta: ' questions' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.515] Event #218: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:33.516] Event #219: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:33.305] Event #193: response.audio_transcript.delta
# 📝 Transcript delta: '’m' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.305] Event #194: response.audio_transcript.delta
# 📝 Transcript delta: ' here' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.315] Event #195: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.324] Event #196: response.audio_transcript.delta
# 📝 Transcript delta: ' make' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.331] Event #197: response.audio_transcript.delta
# 📝 Transcript delta: ' your' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.344] Event #198: response.audio_transcript.delta
# 📝 Transcript delta: ' life' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.359] Event #199: response.audio_transcript.delta
# 📝 Transcript delta: ' a' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.365] Event #200: response.audio_transcript.delta
# 📝 Transcript delta: ' little' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.376] Event #201: response.audio_transcript.delta
# 📝 Transcript delta: ' easier' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.394] Event #202: response.audio_transcript.delta
# 📝 Transcript delta: '.' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.395] Event #203: response.audio_transcript.delta
# 📝 Transcript delta: ' Here' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.411] Event #204: response.audio_transcript.delta
# 📝 Transcript delta: ' are' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.417] Event #205: response.audio_transcript.delta
# 📝 Transcript delta: ' some' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.427] Event #206: response.audio_transcript.delta
# 📝 Transcript delta: ' ways' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.441] Event #207: response.audio_transcript.delta
# 📝 Transcript delta: ' I' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.447] Event #208: response.audio_transcript.delta
# 📝 Transcript delta: ' can' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.459] Event #209: response.audio_transcript.delta
# 📝 Transcript delta: ' help' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.470] Event #210: response.audio_transcript.delta
# 📝 Transcript delta: ':
#
# ' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.481] Event #211: response.audio_transcript.delta
# 📝 Transcript delta: '-' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.490] Event #212: response.audio_transcript.delta
# 📝 Transcript delta: ' **' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.502] Event #213: response.audio.delta
# 🎵 New audio item: item_4ij2qIQdNxtgc29ze1FYsH
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:33.505] Event #214: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:33.506] Event #215: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:33.506] Event #216: response.audio_transcript.delta
# 📝 Transcript delta: 'Answer' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.512] Event #217: response.audio_transcript.delta
# 📝 Transcript delta: ' questions' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.515] Event #218: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:33.516] Event #219: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:33.523] Event #220: response.audio_transcript.delta
# 📝 Transcript delta: ':**' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.529] Event #221: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:33.531] Event #222: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:33.535] Event #223: response.audio_transcript.delta
# 📝 Transcript delta: ' Whether' (item: item_4ij2qIQdNxtgc29ze1FYsH)
# 📨 [00:07:33.545] Event #224: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:33.547] Event #225: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:33.548] Event #226: response.audio_transcript.delta
# ...
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:47.989] Event #1155: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.008] Event #1156: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.035] Event #1157: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:07:48.048] Event #1158: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:48.068] Event #1159: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.094] Event #1160: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:47.905] Event #1152: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:07:47.930] Event #1153: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:47.951] Event #1154: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:47.989] Event #1155: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.008] Event #1156: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.035] Event #1157: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:07:48.048] Event #1158: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:48.068] Event #1159: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.094] Event #1160: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.124] Event #1161: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.149] Event #1162: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:07:48.157] Event #1163: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:48.193] Event #1164: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.209] Event #1165: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.238] Event #1166: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.268] Event #1167: response.audio.delta
# 🔊 Playing audio chunk: 2822 bytes
# 📨 [00:07:48.300] Event #1168: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:48.317] Event #1169: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.124] Event #1161: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.149] Event #1162: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:07:48.157] Event #1163: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:48.193] Event #1164: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.209] Event #1165: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.238] Event #1166: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.268] Event #1167: response.audio.delta
# 🔊 Playing audio chunk: 2822 bytes
# 📨 [00:07:48.300] Event #1168: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:48.317] Event #1169: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.342] Event #1170: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.374] Event #1171: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.403] Event #1172: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.427] Event #1173: response.audio.delta
# 🔊 Playing audio chunk: 1126 bytes
# 📨 [00:07:48.435] Event #1174: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:48.463] Event #1175: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.492] Event #1176: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.522] Event #1177: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.342] Event #1170: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.374] Event #1171: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.403] Event #1172: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.427] Event #1173: response.audio.delta
# 🔊 Playing audio chunk: 1126 bytes
# 📨 [00:07:48.435] Event #1174: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:48.463] Event #1175: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.492] Event #1176: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.522] Event #1177: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.555] Event #1178: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.580] Event #1179: response.audio.delta
# 🔊 Playing audio chunk: 3526 bytes
# 📨 [00:07:48.603] Event #1180: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:48.630] Event #1181: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.659] Event #1182: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.687] Event #1183: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.715] Event #1184: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.742] Event #1185: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.555] Event #1178: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.580] Event #1179: response.audio.delta
# 🔊 Playing audio chunk: 3526 bytes
# 📨 [00:07:48.603] Event #1180: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:48.630] Event #1181: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.659] Event #1182: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.687] Event #1183: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.715] Event #1184: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.742] Event #1185: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.771] Event #1186: response.audio.delta
# 🔊 Playing audio chunk: 1830 bytes
# 📨 [00:07:48.787] Event #1187: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:48.813] Event #1188: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.841] Event #1189: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.869] Event #1190: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.896] Event #1191: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:07:48.899] Event #1192: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:48.928] Event #1193: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.957] Event #1194: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:48.771] Event #1186: response.audio.delta
# 🔊 Playing audio chunk: 1830 bytes
# 📨 [00:07:48.787] Event #1187: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:48.813] Event #1188: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.841] Event #1189: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.869] Event #1190: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.896] Event #1191: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:07:48.899] Event #1192: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:48.928] Event #1193: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:48.957] Event #1194: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:48.985] Event #1195: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.013] Event #1196: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:49.016] Event #1197: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.042] Event #1198: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:49.050] Event #1199: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.075] Event #1200: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:49.083] Event #1201: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.108] Event #1202: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:49.115] Event #1203: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.143] Event #1204: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:49.165] Event #1205: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.195] Event #1206: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:48.985] Event #1195: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.013] Event #1196: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:49.016] Event #1197: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.042] Event #1198: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:49.050] Event #1199: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.075] Event #1200: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:49.083] Event #1201: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.108] Event #1202: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:07:49.115] Event #1203: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.143] Event #1204: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:49.165] Event #1205: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.195] Event #1206: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:49.215] Event #1207: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.243] Event #1208: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:49.266] Event #1209: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.295] Event #1210: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:49.318] Event #1211: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.343] Event #1212: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.371] Event #1213: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:07:49.386] Event #1214: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.409] Event #1215: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.215] Event #1207: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.243] Event #1208: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:49.266] Event #1209: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.295] Event #1210: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:07:49.318] Event #1211: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.343] Event #1212: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.371] Event #1213: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:07:49.386] Event #1214: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.409] Event #1215: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.437] Event #1216: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:07:49.449] Event #1217: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.478] Event #1218: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.513] Event #1219: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:49.544] Event #1220: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.560] Event #1221: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.588] Event #1222: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:49.619] Event #1223: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.646] Event #1224: response.audio.delta
# 📨 [00:07:49.437] Event #1216: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:07:49.449] Event #1217: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.478] Event #1218: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.513] Event #1219: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:49.544] Event #1220: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.560] Event #1221: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.588] Event #1222: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:07:49.619] Event #1223: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.646] Event #1224: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.681] Event #1225: response.audio.delta
# 🔊 Playing audio chunk: 1594 bytes
# 📨 [00:07:49.686] Event #1226: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.717] Event #1227: response.audio.delta
# 🔊 Playing audio chunk: 524 bytes
# 📨 [00:07:49.721] Event #1228: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.742] Event #1229: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.769] Event #1230: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.804] Event #1231: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:07:49.815] Event #1232: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.843] Event #1233: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.681] Event #1225: response.audio.delta
# 🔊 Playing audio chunk: 1594 bytes
# 📨 [00:07:49.686] Event #1226: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.717] Event #1227: response.audio.delta
# 🔊 Playing audio chunk: 524 bytes
# 📨 [00:07:49.721] Event #1228: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.742] Event #1229: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.769] Event #1230: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.804] Event #1231: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:07:49.815] Event #1232: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:07:49.843] Event #1233: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.870] Event #1234: response.audio.delta
# 🔊 Playing audio chunk: 2992 bytes
# 📨 [00:07:49.891] Event #1235: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.916] Event #1236: response.audio.delta
# 🔊 Playing audio chunk: 1526 bytes
# 📨 [00:07:49.928] Event #1237: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 🛑 Shutting down...
# 📨 [00:07:49.959] Event #1238: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.870] Event #1234: response.audio.delta
# 🔊 Playing audio chunk: 2992 bytes
# 📨 [00:07:49.891] Event #1235: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:07:49.916] Event #1236: response.audio.delta
# 🔊 Playing audio chunk: 1526 bytes
# 📨 [00:07:49.928] Event #1237: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 🛑 Shutting down...
# 📨 [00:07:49.959] Event #1238: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# ✅ Audio playback thread completed (1238 events processed)
# 🔌 Closing WebSocket connection (ID: e401a950)...
# 🔌 WebSocket connection closed (ID: e401a950)
#    Status: None, Message: None
# ✅ Audio playback thread completed (1238 events processed)
# 🔌 Closing WebSocket connection (ID: e401a950)...
# 🔌 WebSocket connection closed (ID: e401a950)
#    Status: None, Message: None
# ✅ Connection closed (ID: e401a950, 1250 messages processed)
# ✅ WebSocket connection closed properly
# ✅ Voice chat cleanup completed
# ✅ Connection closed (ID: e401a950, 1250 messages processed)
# ✅ WebSocket connection closed properly
# ✅ Voice chat cleanup completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 14
#      11 print("Watch for error messages and connection status")
#      13 # Uncomment the line below to run debug version:
# ---> 14 run_voice_chat_debug()
#      16 print("💡 Uncomment the line above to run the debug version")
#
# Cell In[14], line 107, in run_voice_chat_debug()
#     104             remaining = max_runtime - elapsed
#     105             print(f"📊 Running {elapsed}s... Threads alive. {remaining}s remaining. Speak into your microphone!")
# --> 107         time.sleep(1)
#     109 except Exception as e:
#     110     print(f"❌ Error in voice chat: {e}")
#
# KeyboardInterrupt:

# %% [markdown]
# ## **12. Azure AI Agent Service Integration**
#
# Azure AI Agent Service provides enterprise-grade conversational AI with:
# - **Centralized prompt management** in Azure AI Foundry portal
# - **Version-controlled agent configurations**
# - **Multi-tenant agent deployment**
# - **Business logic separation** from client code
#
# ### **Agent vs Direct Model Comparison**
#
# | Aspect | Direct Model | Azure AI Agent Service |
# |--------|--------------|-------------------------|
# | **Instructions** | Client-side code | Azure portal managed |
# | **Updates** | Code deployment | Portal configuration |
# | **Scalability** | Manual management | Enterprise multi-tenant |
# | **Governance** | Developer-controlled | Business-user accessible |
#
# ### **Environment Configuration**
#
# **Standard AI Foundry Projects (Recommended):**
# ```env
# # Required for AI Foundry Projects
# AI_FOUNDRY_PROJECT_NAME=your-project-name
# AI_FOUNDRY_AGENT_ID=asst_xxxxxxxxxxxxx
#
# # Standard Voice Live API
# AZURE_VOICE_LIVE_ENDPOINT=https://your-resource.cognitiveservices.azure.com
# AZURE_VOICE_LIVE_API_VERSION=2025-05-01-preview
# ```
#
# **Hub-based Projects (Legacy):**
# ```env
# # Required for Hub-based Projects
# AI_FOUNDRY_AGENT_ID=asst_xxxxxxxxxxxxx
# AI_FOUNDRY_AGENT_CONNECTION_STRING=your-connection-string
#
# # Standard Voice Live API
# AZURE_VOICE_LIVE_ENDPOINT=https://your-resource.cognitiveservices.azure.com
# AZURE_VOICE_LIVE_API_VERSION=2025-05-01-preview
# ```
#
# **Note:** Most users should use the standard AI Foundry project approach with `PROJECT_NAME` + `AGENT_ID`. The connection string is only needed for legacy hub-based deployments.

# %%
class AzureVoiceLiveAgent:
    """
    Enterprise Azure Voice Live client with Agent Service integration.
    
    Supports both AI Foundry project-based (recommended) and hub-based deployments.
    """
    
    def __init__(self, azure_endpoint: str, api_version: str = "2025-05-01-preview"):
        self._azure_endpoint = azure_endpoint
        self._api_version = api_version
        self._credential = DefaultAzureCredential()
        self._connection = None
    
    def connect_agent(self, project_name: str = None, agent_id: str = None, 
                     connection_string: str = None) -> VoiceLiveConnection:
        """
        Connect to Azure AI Agent Service.
        
        Standard AI Foundry Projects (Recommended):
            project_name: AI Foundry project name
            agent_id: Agent ID from Azure portal
            
        Hub-based Projects (Legacy):
            agent_id: Agent ID from Azure portal  
            connection_string: Connection string from Azure portal
        """
        if not agent_id:
            raise ValueError("Agent ID is required")
            
        # Get authentication tokens
        voice_token = self._credential.get_token("https://ai.azure.com/.default")
        
        # Build WebSocket URL
        ws_endpoint = self._azure_endpoint.replace("https://", "wss://")
        
        if project_name:
            # Standard AI Foundry project-based deployment (recommended)
            agent_token = voice_token  # Use same token for project-based
            url = (f"{ws_endpoint}/voice-live/realtime?"
                   f"api-version={self._api_version}&"
                   f"agent-project-name={project_name}&"
                   f"agent-id={agent_id}&"
                   f"agent-access-token={agent_token.token}")
            print(f"✅ Using AI Foundry project: {project_name}")
            
        elif connection_string:
            # Hub-based deployment (legacy)
            agent_token = self._credential.get_token("https://ml.azure.com/.default")
            url = (f"{ws_endpoint}/voice-live/realtime?"
                   f"api-version={self._api_version}&"
                   f"agent-connection-string={connection_string}&"
                   f"agent-id={agent_id}&"
                   f"agent-access-token={agent_token.token}")
            print(f"✅ Using hub-based connection (legacy)")
            
        else:
            raise ValueError("Either project_name (recommended) or connection_string (legacy) is required")
        
        # Setup headers
        headers = {
            "Authorization": f"Bearer {voice_token.token}",
            "x-ms-client-request-id": str(uuid.uuid4())
        }
        
        # Create and connect
        self._connection = VoiceLiveConnection(url, headers)
        self._connection.connect()
        return self._connection
    
    def create_agent_session_config(self, voice_name: str = "en-US-Ava:DragonHDLatestNeural") -> dict:
        """Create optimized session configuration for agent deployment."""
        return {
            "type": "session.update",
            "session": {
                "turn_detection": {
                    "type": "azure_semantic_vad",
                    "threshold": 0.3,
                    "prefix_padding_ms": 200,
                    "silence_duration_ms": 200,
                    "remove_filler_words": False,
                    "end_of_utterance_detection": {
                        "model": "semantic_detection_v1",
                        "threshold": 0.01,
                        "timeout": 2,
                    },
                },
                "input_audio_noise_reduction": {"type": "azure_deep_noise_suppression"},
                "input_audio_echo_cancellation": {"type": "server_echo_cancellation"},
                "voice": {
                    "name": voice_name,
                    "type": "azure-standard", 
                    "temperature": 0.8,
                },
            },
            "event_id": ""
        }

# Initialize enterprise agent client
agent_client = AzureVoiceLiveAgent(
    azure_endpoint=AZURE_VOICE_LIVE_ENDPOINT,
    api_version=AZURE_VOICE_LIVE_API_VERSION
)

print("✅ Enterprise Azure Voice Live Agent client initialized")
print(f"   Endpoint: {AZURE_VOICE_LIVE_ENDPOINT}")
print(f"   API Version: {AZURE_VOICE_LIVE_API_VERSION}")
print("   Deployment: Standard AI Foundry project (recommended) or hub-based (legacy)")
# Out:
# ✅ Enterprise Azure Voice Live Agent client initialized
#    Endpoint: https://poc-ai-agents-voice-resource.cognitiveservices.azure.com/
#    API Version: 2025-05-01-preview
#    Deployment: Standard AI Foundry project (recommended) or hub-based (legacy)

# %%
def run_agent_voice_application():
    """
    Run Azure AI Agent Service voice application with comprehensive event logging.
    
    Enterprise-grade implementation with proper error handling,
    logging, and graceful shutdown.
    """
    global stop_event
    connection = None
    threads = []
    
    # Check if already running
    if not stop_event.is_set():
        print("⚠️  Stopping any previous instance...")
        stop_event.set()
        time.sleep(2)
    
    try:
        stop_event.clear()
        
        print("🚀 Starting Azure AI Agent Service voice application")
        print(f"   Timestamp: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
        
        # Load agent configuration from environment
        project_name = os.environ.get("AI_FOUNDRY_PROJECT_NAME")
        agent_id = os.environ.get("AI_FOUNDRY_AGENT_ID") 
        connection_string = os.environ.get("AI_FOUNDRY_AGENT_CONNECTION_STRING")
        
        print(f"📋 Configuration Check:")
        print(f"   Project Name: {project_name or '❌ Not set'}")
        print(f"   Agent ID: {agent_id or '❌ Not set'}")
        print(f"   Connection String: {'✅ Set' if connection_string else '❌ Not set (hub-based only)'}")
        
        if not agent_id:
            raise ValueError("AI_FOUNDRY_AGENT_ID environment variable required")
        
        # Determine deployment type and connect
        if project_name:
            deployment_type = "AI Foundry Project (Recommended)"
            print(f"✅ Using deployment type: {deployment_type}")
            print(f"   Agent ID: {agent_id}")
            print(f"   Project: {project_name}")
            
            # Connect using project name (recommended)
            print("🔌 Connecting to Azure AI Agent Service...")
            connection = agent_client.connect_agent(
                project_name=project_name,
                agent_id=agent_id
            )
            
        elif connection_string:
            deployment_type = "Hub-based (Legacy)"
            print(f"✅ Using deployment type: {deployment_type}")
            print(f"   Agent ID: {agent_id}")
            
            # Connect using connection string (legacy)
            print("🔌 Connecting to Azure AI Agent Service...")
            connection = agent_client.connect_agent(
                agent_id=agent_id,
                connection_string=connection_string
            )
            
        else:
            raise ValueError(
                "Either AI_FOUNDRY_PROJECT_NAME (recommended) or "
                "AI_FOUNDRY_AGENT_CONNECTION_STRING (legacy) is required"
            )
        
        print("✅ Connected to Azure AI Agent Service")
        
        # Configure session
        print("⚙️  Configuring agent session...")
        session_config = agent_client.create_agent_session_config()
        connection.send(json.dumps(session_config))
        print("✅ Agent session configuration sent")
        
        # Wait a moment for session to be established
        print("⏳ Waiting for session establishment...")
        time.sleep(2)
        
        # Start audio processing threads
        print("🧵 Starting audio processing threads...")
        
        def safe_listen_and_send_audio(connection):
            try:
                listen_and_send_audio(connection)
            except Exception as e:
                print(f"❌ Audio input thread error: {e}")
                logger.error(f"Audio input error: {e}")
                stop_event.set()
        
        def safe_receive_audio_and_playback(connection):
            try:
                receive_audio_and_playback(connection)
            except Exception as e:
                print(f"❌ Audio output thread error: {e}")
                logger.error(f"Audio output error: {e}")
                stop_event.set()
        
        def safe_read_keyboard_and_quit():
            try:
                read_keyboard_and_quit()
            except Exception as e:
                print(f"❌ Keyboard input thread error: {e}")
                logger.error(f"Keyboard input error: {e}")
                stop_event.set()
        
        audio_threads = [
            threading.Thread(target=safe_listen_and_send_audio, args=(connection,), name="AudioInput"),
            threading.Thread(target=safe_receive_audio_and_playback, args=(connection,), name="AudioOutput"),
            threading.Thread(target=safe_read_keyboard_and_quit, name="UserInput")
        ]
        
        for i, thread in enumerate(audio_threads):
            thread.start()
            threads.append(thread)
            print(f"   ✅ Thread {i+1} started: {thread.name}")
        
        print("=" * 60)
        print("🎙️  Agent voice application is now ACTIVE!")
        print("💬 Start speaking - your conversation is managed by the Azure AI agent")
        print("📊 All events will be logged below")
        print("⌨️  Press 'q' + Enter to quit")
        print("=" * 60)
        
        # Wait for user to quit or error
        threads[2].join()  # Wait for keyboard thread
        
    except Exception as e:
        print(f"❌ Application error: {e}")
        logger.error(f"Agent application error: {e}")
        import traceback
        traceback.print_exc()
        
    finally:
        print("\n" + "=" * 60)
        print("🛑 Shutting down agent application...")
        stop_event.set()
        
        # Wait for threads with timeout
        print("⏳ Waiting for threads to complete...")
        for i, thread in enumerate(threads):
            if thread.is_alive():
                print(f"   Stopping thread {i+1}: {thread.name}")
                thread.join(timeout=5)
                if thread.is_alive():
                    print(f"   ⚠️  Thread {i+1} ({thread.name}) did not stop gracefully")
                else:
                    print(f"   ✅ Thread {i+1} ({thread.name}) stopped")
        
        # Close connection
        if connection:
            try:
                print("🔌 Closing agent connection...")
                connection.close()
                print("✅ Agent connection closed successfully")
            except Exception as e:
                print(f"⚠️  Connection cleanup error: {e}")
                logger.error(f"Connection cleanup error: {e}")
        else:
            print("ℹ️  No connection to close")
        
        print("✅ Azure AI Agent Service application shutdown complete")
        print("=" * 60)

print("✅ Azure AI Agent Service voice application function ready")
print("   This provides comprehensive event logging for debugging and monitoring")
# Out:
# ✅ Azure AI Agent Service voice application function ready
#    This provides comprehensive event logging for debugging and monitoring

# %% [markdown]
# ## **13. Run Azure AI Agent Service Application**
#
# ### **Production Voice Application**
#
# Execute the enterprise-grade voice application with comprehensive event logging and Azure AI Agent Service integration.
#
# **Prerequisites:**
# - Azure AI Foundry resource with Voice Live API enabled
# - Created agent in Azure AI Foundry portal
# - Environment variables configured (see below)
# - Audio devices (headset recommended for production)
#
# **Required Environment Variables:**
# - `AI_FOUNDRY_AGENT_ID` - Your agent ID from Azure AI Foundry portal
# - `AI_FOUNDRY_PROJECT_NAME` - Your project name (recommended for standard projects)
#
# **Optional (Legacy Hub-based Projects):**
# - `AI_FOUNDRY_AGENT_CONNECTION_STRING` - Only needed for hub-based deployments

# %%
run_agent_voice_application()
# Out:
# 🚀 Starting Azure AI Agent Service voice application
#    Timestamp: 2025-09-02 00:08:12
# 📋 Configuration Check:
#    Project Name: poc-ai-agents-voice
#    Agent ID: asst_Dd9U7mxFgfZxjwhEbSr76dyU
#    Connection String: ❌ Not set (hub-based only)
# ✅ Using deployment type: AI Foundry Project (Recommended)
#    Agent ID: asst_Dd9U7mxFgfZxjwhEbSr76dyU
#    Project: poc-ai-agents-voice
# 🔌 Connecting to Azure AI Agent Service...
# ✅ Using AI Foundry project: poc-ai-agents-voice
# 🔌 Establishing WebSocket connection (ID: 0736c5e3)...
# ✅ Using AI Foundry project: poc-ai-agents-voice
# 🔌 Establishing WebSocket connection (ID: 0736c5e3)...
# ✅ WebSocket connection opened (ID: 0736c5e3)
# ✅ Connection established successfully (ID: 0736c5e3)
# ✅ Connected to Azure AI Agent Service
# ⚙️  Configuring agent session...
# ✅ Agent session configuration sent
# ⏳ Waiting for session establishment...
# ✅ WebSocket connection opened (ID: 0736c5e3)
# ✅ Connection established successfully (ID: 0736c5e3)
# ✅ Connected to Azure AI Agent Service
# ⚙️  Configuring agent session...
# ✅ Agent session configuration sent
# ⏳ Waiting for session establishment...
# 🧵 Starting audio processing threads...
#    ✅ Thread 1 started: AudioInput
#    ✅ Thread 2 started: AudioOutput
# Press 'q' and Enter to quit the chat.
#    ✅ Thread 3 started: UserInput
# ============================================================
# 🎙️  Agent voice application is now ACTIVE!
# 💬 Start speaking - your conversation is managed by the Azure AI agent
# 📊 All events will be logged below
# ⌨️  Press 'q' + Enter to quit
# ============================================================
# 🧵 Starting audio processing threads...
#    ✅ Thread 1 started: AudioInput
#    ✅ Thread 2 started: AudioOutput
# Press 'q' and Enter to quit the chat.
#    ✅ Thread 3 started: UserInput
# ============================================================
# 🎙️  Agent voice application is now ACTIVE!
# 💬 Start speaking - your conversation is managed by the Azure AI agent
# 📊 All events will be logged below
# ⌨️  Press 'q' + Enter to quit
# ============================================================
# 🎧 Audio playback thread started - monitoring events...
# 📨 [00:08:19.776] Event #1: session.created
# ✅ Session created: sess_5KkHOrMOvUouSfljbddiGx
#    Instructions:
# You are a helpful customer support agent for Demo Corp. Your role is to:
#
# 🎯 **Primary Responsibilit...
#    Voice: en-US-AvaNeural
# 📨 [00:08:19.777] Event #2: session.updated
# 🔄 Session updated
#    Voice: en-US-Ava:DragonHDLatestNeural
#    VAD: azure_semantic_vad
# 📨 [00:08:22.377] Event #3: input_audio_buffer.speech_started
# 🗣️  Speech started - stopping AI playback
# 📨 [00:08:23.281] Event #4: input_audio_buffer.speech_stopped
# 🤐 Speech stopped - processing...
# 📨 [00:08:23.285] Event #5: input_audio_buffer.committed
# 🎤 Audio buffer committed: item_1roOtH9YQhy31IGguBnngF
# 📨 [00:08:23.479] Event #6: conversation.item.input_audio_transcription.completed
# ❓ Unknown event: conversation.item.input_audio_transcription.completed
# 📨 [00:08:23.482] Event #7: conversation.item.created
# 📝 Item created: message (item_1roOtH9YQhy31IGguBnngF)
#    Role: user
# 📨 [00:08:23.485] Event #8: response.created
# 🤖 Response created: resp_3yTLmTySNERFxKeUK7ZHlS
# 📨 [00:08:24.852] Event #9: response.output_item.added
# ➕ Output item added: message (item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.854] Event #10: conversation.item.created
# 📝 Item created: message (item_6fjxD246E98cYsx5Co1tvR)
#    Role: assistant
# 📨 [00:08:24.855] Event #11: response.content_part.added
# 🧩 Content part added: audio
# 📨 [00:08:24.855] Event #12: response.audio_transcript.delta
# 📝 Transcript delta: 'Hello' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.858] Event #13: response.audio_transcript.delta
# 📝 Transcript delta: '!' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.864] Event #14: response.audio_transcript.delta
# 📝 Transcript delta: ' I'm' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.868] Event #15: response.audio_transcript.delta
# 📝 Transcript delta: ' here' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.873] Event #16: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.883] Event #17: response.audio_transcript.delta
# 📝 Transcript delta: ' assist' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.888] Event #18: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.894] Event #19: response.audio_transcript.delta
# 📝 Transcript delta: ' with' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.906] Event #20: response.audio_transcript.delta
# 📝 Transcript delta: ' any' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.950] Event #21: response.audio_transcript.delta
# 📝 Transcript delta: ' questions' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.952] Event #22: response.audio_transcript.delta
# 📝 Transcript delta: ' or' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.960] Event #23: response.audio_transcript.delta
# 📝 Transcript delta: ' issues' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.966] Event #24: response.audio_transcript.delta
# 📝 Transcript delta: ' related' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.970] Event #25: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.975] Event #26: response.audio_transcript.delta
# 📝 Transcript delta: ' Demo' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.981] Event #27: response.audio_transcript.delta
# 📝 Transcript delta: ' Corp' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.986] Event #28: response.audio_transcript.delta
# 📝 Transcript delta: ' products' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.998] Event #29: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.057] Event #30: response.audio.delta
# 🎵 New audio item: item_6fjxD246E98cYsx5Co1tvR
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.064] Event #31: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.065] Event #32: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:25.075] Event #33: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.077] Event #34: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:25.087] Event #35: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.087] Event #36: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:25.104] Event #37: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.106] Event #38: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:25.108] Event #39: response.audio_transcript.delta
# 📝 Transcript delta: ' orders' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.110] Event #40: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.112] Event #41: response.audio_transcript.delta
# 📝 Transcript delta: ' or' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.117] Event #42: response.audio_transcript.delta
# 📝 Transcript delta: ' services' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.119] Event #43: response.audio_transcript.delta
# 📝 Transcript delta: '.' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.119] Event #44: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.120] Event #45: response.audio_transcript.delta
# 📝 Transcript delta: ' How' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.122] Event #46: response.audio_transcript.delta
# 📝 Transcript delta: ' can' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.126] Event #47: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.129] Event #48: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:08:25.129] Event #49: response.audio_transcript.delta
# 📝 Transcript delta: ' I' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.131] Event #50: response.audio_transcript.delta
# 📝 Transcript delta: ' help' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.131] Event #51: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.132] Event #52: response.audio_transcript.delta
# 📝 Transcript delta: ' today' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.132] Event #53: response.audio_transcript.delta
# 📝 Transcript delta: '?' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.132] Event #54: response.audio_transcript.delta
# 📝 Transcript delta: ' 😊' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.295] Event #55: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.301] Event #56: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.305] Event #57: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:25.315] Event #58: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.316] Event #59: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:25.330] Event #60: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.333] Event #61: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:25.343] Event #62: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.343] Event #63: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:25.356] Event #64: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.356] Event #65: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:25.380] Event #66: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.385] Event #67: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:25.402] Event #68: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.406] Event #69: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:25.427] Event #70: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.430] Event #71: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:25.449] Event #72: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.452] Event #73: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:25.485] Event #74: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.489] Event #75: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.491] Event #76: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:08:25.507] Event #77: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.511] Event #78: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.511] Event #79: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:08:25.549] Event #80: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.551] Event #81: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.552] Event #82: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:25.582] Event #83: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.586] Event #84: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.589] Event #85: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:25.623] Event #86: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.627] Event #87: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.632] Event #88: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.636] Event #89: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:08:25.667] Event #90: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.671] Event #91: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.676] Event #92: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.676] Event #93: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:08:25.718] Event #94: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.726] Event #95: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.727] Event #96: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.733] Event #97: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.734] Event #98: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:08:25.769] Event #99: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.772] Event #100: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.778] Event #101: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.779] Event #102: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.780] Event #103: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:08:25.825] Event #104: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.829] Event #105: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.837] Event #106: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.840] Event #107: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.840] Event #108: response.audio.delta
# 🔊 Playing audio chunk: 2822 bytes
# 📨 [00:08:25.888] Event #109: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.892] Event #110: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.896] Event #111: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.902] Event #112: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.907] Event #113: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.907] Event #114: response.audio.delta
# 🔊 Playing audio chunk: 1126 bytes
# 📨 [00:08:25.960] Event #115: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.964] Event #116: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.970] Event #117: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.974] Event #118: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.982] Event #119: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.984] Event #120: response.audio.delta
# 🔊 Playing audio chunk: 3286 bytes
# 📨 [00:08:25.984] Event #121: response.audio.delta
# 🔊 Playing audio chunk: 240 bytes
# 📨 [00:08:26.041] Event #122: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.044] Event #123: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.052] Event #124: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.058] Event #125: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.058] Event #126: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.063] Event #127: response.audio.delta
# 🔊 Playing audio chunk: 3286 bytes
# 📨 [00:08:26.065] Event #128: response.audio.delta
# 🔊 Playing audio chunk: 2640 bytes
# 📨 [00:08:26.085] Event #129: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.086] Event #130: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.093] Event #131: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.096] Event #132: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.099] Event #133: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.100] Event #134: response.audio.delta
# 🔊 Playing audio chunk: 1126 bytes
# 📨 [00:08:26.201] Event #135: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.205] Event #136: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.209] Event #137: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:26.219] Event #138: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.222] Event #139: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:26.231] Event #140: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.232] Event #141: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:26.247] Event #142: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.251] Event #143: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:26.262] Event #144: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.264] Event #145: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:26.295] Event #146: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.300] Event #147: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:26.315] Event #148: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.322] Event #149: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:26.344] Event #150: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.374] Event #151: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.413] Event #152: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:26.434] Event #153: response.audio.done
# ✅ Audio complete: item_6fjxD246E98cYsx5Co1tvR
# 📨 [00:08:26.436] Event #154: response.audio_transcript.done
# ❓ Unknown event: response.audio_transcript.done
# 📨 [00:08:26.438] Event #155: response.content_part.done
# ✅ Content part done: audio
# 📨 [00:08:26.442] Event #156: response.output_item.done
# ✅ Output item done: message (item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:26.445] Event #157: response.done
# ✅ Response complete: resp_3yTLmTySNERFxKeUK7ZHlS (status: cancelled)
# 📨 [00:08:35.327] Event #158: input_audio_buffer.speech_started
# 🗣️  Speech started - stopping AI playback
# 📨 [00:08:37.161] Event #159: input_audio_buffer.speech_stopped
# 🤐 Speech stopped - processing...
# 📨 [00:08:37.163] Event #160: input_audio_buffer.committed
# 🎤 Audio buffer committed: item_61ByE9Q5MUKDe1sNY6Y1vN
# 📨 [00:08:37.391] Event #161: conversation.item.input_audio_transcription.completed
# ❓ Unknown event: conversation.item.input_audio_transcription.completed
# 📨 [00:08:37.393] Event #162: conversation.item.created
# 📝 Item created: message (item_61ByE9Q5MUKDe1sNY6Y1vN)
#    Role: user
# 📨 [00:08:37.394] Event #163: response.created
# 🤖 Response created: resp_3O5YEz97QKz5VbFr4e2eQj
# 📨 [00:08:38.762] Event #164: response.output_item.added
# ➕ Output item added: message (item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.767] Event #165: conversation.item.created
# 📝 Item created: message (item_2gkxiUkYIrY9yNyxsscXX8)
#    Role: assistant
# 📨 [00:08:38.768] Event #166: response.content_part.added
# 🧩 Content part added: audio
# 📨 [00:08:38.769] Event #167: response.audio_transcript.delta
# 📝 Transcript delta: 'It' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.775] Event #168: response.audio_transcript.delta
# 📝 Transcript delta: ' sounds' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.777] Event #169: response.audio_transcript.delta
# 📝 Transcript delta: ' like' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.778] Event #170: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.780] Event #171: response.audio_transcript.delta
# 📝 Transcript delta: '’re' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.797] Event #172: response.audio_transcript.delta
# 📝 Transcript delta: ' good' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.844] Event #173: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.851] Event #174: response.audio_transcript.delta
# 📝 Transcript delta: ' go' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.868] Event #175: response.audio_transcript.delta
# 📝 Transcript delta: ' right' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.869] Event #176: response.audio_transcript.delta
# 📝 Transcript delta: ' now' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.873] Event #177: response.audio_transcript.delta
# 📝 Transcript delta: '—' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.879] Event #178: response.audio_transcript.delta
# 📝 Transcript delta: 'gl' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.887] Event #179: response.audio_transcript.delta
# 📝 Transcript delta: 'ad' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.945] Event #180: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.953] Event #181: response.audio_transcript.delta
# 📝 Transcript delta: ' hear' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.960] Event #182: response.audio_transcript.delta
# 📝 Transcript delta: ' it' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.964] Event #183: response.audio_transcript.delta
# 📝 Transcript delta: '!' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.050] Event #184: response.audio_transcript.delta
# 📝 Transcript delta: ' 😊' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.052] Event #185: response.audio_transcript.delta
# 📝 Transcript delta: ' If' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.060] Event #186: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.068] Event #187: response.audio_transcript.delta
# 📝 Transcript delta: ' ever' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.145] Event #188: response.audio_transcript.delta
# 📝 Transcript delta: ' need' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.153] Event #189: response.audio_transcript.delta
# 📝 Transcript delta: ' help' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.157] Event #190: response.audio_transcript.delta
# 📝 Transcript delta: ' with' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.168] Event #191: response.audio_transcript.delta
# 📝 Transcript delta: ' anything' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.170] Event #192: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.178] Event #193: response.audio.delta
# 🎵 New audio item: item_2gkxiUkYIrY9yNyxsscXX8
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.189] Event #194: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.191] Event #195: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:39.194] Event #196: response.audio_transcript.delta
# 📝 Transcript delta: ' feel' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.196] Event #197: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.196] Event #198: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:39.212] Event #199: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.214] Event #200: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:39.229] Event #201: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.231] Event #202: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:39.245] Event #203: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.246] Event #204: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:39.265] Event #205: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.271] Event #206: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:39.272] Event #207: response.audio_transcript.delta
# 📝 Transcript delta: ' free' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.275] Event #208: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.276] Event #209: response.audio_transcript.delta
# 📝 Transcript delta: ' reach' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.277] Event #210: response.audio_transcript.delta
# 📝 Transcript delta: ' out' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.278] Event #211: response.audio_transcript.delta
# 📝 Transcript delta: '.' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.279] Event #212: response.audio_transcript.delta
# 📝 Transcript delta: ' Have' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.286] Event #213: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.291] Event #214: response.audio_transcript.delta
# 📝 Transcript delta: ' a' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.293] Event #215: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:39.294] Event #216: response.audio_transcript.delta
# 📝 Transcript delta: ' fantastic' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.311] Event #217: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.315] Event #218: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:39.333] Event #219: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.339] Event #220: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:39.342] Event #221: response.audio_transcript.delta
# 📝 Transcript delta: ' day' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.348] Event #222: response.audio_transcript.delta
# 📝 Transcript delta: '!' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.357] Event #223: response.audio_transcript.delta
# 📝 Transcript delta: ' 🚀' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.365] Event #224: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.371] Event #225: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.375] Event #226: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:08:39.392] Event #227: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.400] Event #228: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.401] Event #229: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:08:39.432] Event #230: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.435] Event #231: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.441] Event #232: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:39.480] Event #233: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.493] Event #234: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.494] Event #235: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:39.508] Event #236: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.514] Event #237: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.525] Event #238: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.526] Event #239: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:08:39.552] Event #240: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.558] Event #241: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.566] Event #242: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.568] Event #243: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:08:39.604] Event #244: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.611] Event #245: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.621] Event #246: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.627] Event #247: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.634] Event #248: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:08:39.635] Event #249: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.643] Event #250: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.650] Event #251: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.655] Event #252: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:08:39.752] Event #253: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.762] Event #254: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.778] Event #255: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:39.790] Event #256: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.795] Event #257: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:39.804] Event #258: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.807] Event #259: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:39.807] Event #260: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.810] Event #261: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:39.817] Event #262: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.819] Event #263: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:39.836] Event #264: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.842] Event #265: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:39.923] Event #266: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.930] Event #267: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:39.937] Event #268: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.942] Event #269: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:39.944] Event #270: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.955] Event #271: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:39.972] Event #272: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.975] Event #273: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.976] Event #274: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:08:39.984] Event #275: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.992] Event #276: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.998] Event #277: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:08:40.012] Event #278: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.020] Event #279: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.023] Event #280: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:40.034] Event #281: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.042] Event #282: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.052] Event #283: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:40.085] Event #284: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.097] Event #285: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.099] Event #286: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.101] Event #287: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:08:40.108] Event #288: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.114] Event #289: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.129] Event #290: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.134] Event #291: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.136] Event #292: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:08:40.223] Event #293: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.234] Event #294: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.249] Event #295: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:40.252] Event #296: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.261] Event #297: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:40.266] Event #298: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.270] Event #299: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:40.279] Event #300: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.283] Event #301: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:40.294] Event #302: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.301] Event #303: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:40.310] Event #304: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.318] Event #305: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:40.327] Event #306: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.334] Event #307: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:40.356] Event #308: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.357] Event #309: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:40.373] Event #310: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.382] Event #311: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:40.388] Event #312: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.398] Event #313: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.403] Event #314: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:08:40.405] Event #315: response.audio.done
# ✅ Audio complete: item_2gkxiUkYIrY9yNyxsscXX8
# 📨 [00:08:40.407] Event #316: response.audio_transcript.done
# ❓ Unknown event: response.audio_transcript.done
# 📨 [00:08:40.409] Event #317: response.content_part.done
# ✅ Content part done: audio
# 📨 [00:08:40.412] Event #318: response.output_item.done
# ✅ Output item done: message (item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:40.414] Event #319: response.done
# ✅ Response complete: resp_3O5YEz97QKz5VbFr4e2eQj (status: cancelled)
# 🎧 Audio playback thread started - monitoring events...
# 📨 [00:08:19.776] Event #1: session.created
# ✅ Session created: sess_5KkHOrMOvUouSfljbddiGx
#    Instructions:
# You are a helpful customer support agent for Demo Corp. Your role is to:
#
# 🎯 **Primary Responsibilit...
#    Voice: en-US-AvaNeural
# 📨 [00:08:19.777] Event #2: session.updated
# 🔄 Session updated
#    Voice: en-US-Ava:DragonHDLatestNeural
#    VAD: azure_semantic_vad
# 📨 [00:08:22.377] Event #3: input_audio_buffer.speech_started
# 🗣️  Speech started - stopping AI playback
# 📨 [00:08:23.281] Event #4: input_audio_buffer.speech_stopped
# 🤐 Speech stopped - processing...
# 📨 [00:08:23.285] Event #5: input_audio_buffer.committed
# 🎤 Audio buffer committed: item_1roOtH9YQhy31IGguBnngF
# 📨 [00:08:23.479] Event #6: conversation.item.input_audio_transcription.completed
# ❓ Unknown event: conversation.item.input_audio_transcription.completed
# 📨 [00:08:23.482] Event #7: conversation.item.created
# 📝 Item created: message (item_1roOtH9YQhy31IGguBnngF)
#    Role: user
# 📨 [00:08:23.485] Event #8: response.created
# 🤖 Response created: resp_3yTLmTySNERFxKeUK7ZHlS
# 📨 [00:08:24.852] Event #9: response.output_item.added
# ➕ Output item added: message (item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.854] Event #10: conversation.item.created
# 📝 Item created: message (item_6fjxD246E98cYsx5Co1tvR)
#    Role: assistant
# 📨 [00:08:24.855] Event #11: response.content_part.added
# 🧩 Content part added: audio
# 📨 [00:08:24.855] Event #12: response.audio_transcript.delta
# 📝 Transcript delta: 'Hello' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.858] Event #13: response.audio_transcript.delta
# 📝 Transcript delta: '!' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.864] Event #14: response.audio_transcript.delta
# 📝 Transcript delta: ' I'm' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.868] Event #15: response.audio_transcript.delta
# 📝 Transcript delta: ' here' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.873] Event #16: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.883] Event #17: response.audio_transcript.delta
# 📝 Transcript delta: ' assist' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.888] Event #18: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.894] Event #19: response.audio_transcript.delta
# 📝 Transcript delta: ' with' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.906] Event #20: response.audio_transcript.delta
# 📝 Transcript delta: ' any' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.950] Event #21: response.audio_transcript.delta
# 📝 Transcript delta: ' questions' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.952] Event #22: response.audio_transcript.delta
# 📝 Transcript delta: ' or' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.960] Event #23: response.audio_transcript.delta
# 📝 Transcript delta: ' issues' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.966] Event #24: response.audio_transcript.delta
# 📝 Transcript delta: ' related' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.970] Event #25: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.975] Event #26: response.audio_transcript.delta
# 📝 Transcript delta: ' Demo' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.981] Event #27: response.audio_transcript.delta
# 📝 Transcript delta: ' Corp' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.986] Event #28: response.audio_transcript.delta
# 📝 Transcript delta: ' products' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:24.998] Event #29: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.057] Event #30: response.audio.delta
# 🎵 New audio item: item_6fjxD246E98cYsx5Co1tvR
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.064] Event #31: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.065] Event #32: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:25.075] Event #33: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.077] Event #34: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:25.087] Event #35: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.087] Event #36: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:25.104] Event #37: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.106] Event #38: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:25.108] Event #39: response.audio_transcript.delta
# 📝 Transcript delta: ' orders' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.110] Event #40: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.112] Event #41: response.audio_transcript.delta
# 📝 Transcript delta: ' or' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.117] Event #42: response.audio_transcript.delta
# 📝 Transcript delta: ' services' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.119] Event #43: response.audio_transcript.delta
# 📝 Transcript delta: '.' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.119] Event #44: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.120] Event #45: response.audio_transcript.delta
# 📝 Transcript delta: ' How' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.122] Event #46: response.audio_transcript.delta
# 📝 Transcript delta: ' can' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.126] Event #47: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.129] Event #48: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:08:25.129] Event #49: response.audio_transcript.delta
# 📝 Transcript delta: ' I' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.131] Event #50: response.audio_transcript.delta
# 📝 Transcript delta: ' help' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.131] Event #51: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.132] Event #52: response.audio_transcript.delta
# 📝 Transcript delta: ' today' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.132] Event #53: response.audio_transcript.delta
# 📝 Transcript delta: '?' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.132] Event #54: response.audio_transcript.delta
# 📝 Transcript delta: ' 😊' (item: item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:25.295] Event #55: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.301] Event #56: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.305] Event #57: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:25.315] Event #58: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.316] Event #59: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:25.330] Event #60: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.333] Event #61: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:25.343] Event #62: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.343] Event #63: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:25.356] Event #64: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.356] Event #65: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:25.380] Event #66: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.385] Event #67: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:25.402] Event #68: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.406] Event #69: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:25.427] Event #70: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.430] Event #71: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:25.449] Event #72: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.452] Event #73: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:25.485] Event #74: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.489] Event #75: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.491] Event #76: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:08:25.507] Event #77: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.511] Event #78: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.511] Event #79: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:08:25.549] Event #80: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.551] Event #81: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.552] Event #82: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:25.582] Event #83: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.586] Event #84: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.589] Event #85: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:25.623] Event #86: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.627] Event #87: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.632] Event #88: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.636] Event #89: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:08:25.667] Event #90: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.671] Event #91: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.676] Event #92: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.676] Event #93: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:08:25.718] Event #94: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.726] Event #95: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.727] Event #96: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.733] Event #97: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.734] Event #98: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:08:25.769] Event #99: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.772] Event #100: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.778] Event #101: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.779] Event #102: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.780] Event #103: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:08:25.825] Event #104: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.829] Event #105: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.837] Event #106: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.840] Event #107: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.840] Event #108: response.audio.delta
# 🔊 Playing audio chunk: 2822 bytes
# 📨 [00:08:25.888] Event #109: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.892] Event #110: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.896] Event #111: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.902] Event #112: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.907] Event #113: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.907] Event #114: response.audio.delta
# 🔊 Playing audio chunk: 1126 bytes
# 📨 [00:08:25.960] Event #115: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:25.964] Event #116: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.970] Event #117: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.974] Event #118: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.982] Event #119: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:25.984] Event #120: response.audio.delta
# 🔊 Playing audio chunk: 3286 bytes
# 📨 [00:08:25.984] Event #121: response.audio.delta
# 🔊 Playing audio chunk: 240 bytes
# 📨 [00:08:26.041] Event #122: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.044] Event #123: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.052] Event #124: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.058] Event #125: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.058] Event #126: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.063] Event #127: response.audio.delta
# 🔊 Playing audio chunk: 3286 bytes
# 📨 [00:08:26.065] Event #128: response.audio.delta
# 🔊 Playing audio chunk: 2640 bytes
# 📨 [00:08:26.085] Event #129: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.086] Event #130: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.093] Event #131: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.096] Event #132: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.099] Event #133: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.100] Event #134: response.audio.delta
# 🔊 Playing audio chunk: 1126 bytes
# 📨 [00:08:26.201] Event #135: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.205] Event #136: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.209] Event #137: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:26.219] Event #138: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.222] Event #139: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:26.231] Event #140: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.232] Event #141: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:26.247] Event #142: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.251] Event #143: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:26.262] Event #144: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.264] Event #145: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:26.295] Event #146: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.300] Event #147: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:26.315] Event #148: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.322] Event #149: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:26.344] Event #150: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:26.374] Event #151: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:26.413] Event #152: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:26.434] Event #153: response.audio.done
# ✅ Audio complete: item_6fjxD246E98cYsx5Co1tvR
# 📨 [00:08:26.436] Event #154: response.audio_transcript.done
# ❓ Unknown event: response.audio_transcript.done
# 📨 [00:08:26.438] Event #155: response.content_part.done
# ✅ Content part done: audio
# 📨 [00:08:26.442] Event #156: response.output_item.done
# ✅ Output item done: message (item_6fjxD246E98cYsx5Co1tvR)
# 📨 [00:08:26.445] Event #157: response.done
# ✅ Response complete: resp_3yTLmTySNERFxKeUK7ZHlS (status: cancelled)
# 📨 [00:08:35.327] Event #158: input_audio_buffer.speech_started
# 🗣️  Speech started - stopping AI playback
# 📨 [00:08:37.161] Event #159: input_audio_buffer.speech_stopped
# 🤐 Speech stopped - processing...
# 📨 [00:08:37.163] Event #160: input_audio_buffer.committed
# 🎤 Audio buffer committed: item_61ByE9Q5MUKDe1sNY6Y1vN
# 📨 [00:08:37.391] Event #161: conversation.item.input_audio_transcription.completed
# ❓ Unknown event: conversation.item.input_audio_transcription.completed
# ...
# 📝 Transcript delta: 'It' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.775] Event #168: response.audio_transcript.delta
# 📝 Transcript delta: ' sounds' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.777] Event #169: response.audio_transcript.delta
# 📝 Transcript delta: ' like' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.778] Event #170: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.780] Event #171: response.audio_transcript.delta
# 📝 Transcript delta: '’re' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.797] Event #172: response.audio_transcript.delta
# 📝 Transcript delta: ' good' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.844] Event #173: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.851] Event #174: response.audio_transcript.delta
# 📝 Transcript delta: ' go' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.868] Event #175: response.audio_transcript.delta
# 📝 Transcript delta: ' right' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.869] Event #176: response.audio_transcript.delta
# 📝 Transcript delta: ' now' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.873] Event #177: response.audio_transcript.delta
# 📝 Transcript delta: '—' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.879] Event #178: response.audio_transcript.delta
# 📝 Transcript delta: 'gl' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.887] Event #179: response.audio_transcript.delta
# 📝 Transcript delta: 'ad' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.945] Event #180: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.953] Event #181: response.audio_transcript.delta
# 📝 Transcript delta: ' hear' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.960] Event #182: response.audio_transcript.delta
# 📝 Transcript delta: ' it' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:38.964] Event #183: response.audio_transcript.delta
# 📝 Transcript delta: '!' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.050] Event #184: response.audio_transcript.delta
# 📝 Transcript delta: ' 😊' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.052] Event #185: response.audio_transcript.delta
# 📝 Transcript delta: ' If' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.060] Event #186: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.068] Event #187: response.audio_transcript.delta
# 📝 Transcript delta: ' ever' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.145] Event #188: response.audio_transcript.delta
# 📝 Transcript delta: ' need' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.153] Event #189: response.audio_transcript.delta
# 📝 Transcript delta: ' help' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.157] Event #190: response.audio_transcript.delta
# 📝 Transcript delta: ' with' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.168] Event #191: response.audio_transcript.delta
# 📝 Transcript delta: ' anything' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.170] Event #192: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.178] Event #193: response.audio.delta
# 🎵 New audio item: item_2gkxiUkYIrY9yNyxsscXX8
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.189] Event #194: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.191] Event #195: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:39.194] Event #196: response.audio_transcript.delta
# 📝 Transcript delta: ' feel' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.196] Event #197: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.196] Event #198: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:39.212] Event #199: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.214] Event #200: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:39.229] Event #201: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.231] Event #202: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:39.245] Event #203: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.246] Event #204: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:39.265] Event #205: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.271] Event #206: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:39.272] Event #207: response.audio_transcript.delta
# 📝 Transcript delta: ' free' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.275] Event #208: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.276] Event #209: response.audio_transcript.delta
# 📝 Transcript delta: ' reach' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.277] Event #210: response.audio_transcript.delta
# 📝 Transcript delta: ' out' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.278] Event #211: response.audio_transcript.delta
# 📝 Transcript delta: '.' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.279] Event #212: response.audio_transcript.delta
# 📝 Transcript delta: ' Have' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.286] Event #213: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.291] Event #214: response.audio_transcript.delta
# 📝 Transcript delta: ' a' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.293] Event #215: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:39.294] Event #216: response.audio_transcript.delta
# 📝 Transcript delta: ' fantastic' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.311] Event #217: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.315] Event #218: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:39.333] Event #219: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.339] Event #220: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:39.342] Event #221: response.audio_transcript.delta
# 📝 Transcript delta: ' day' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.348] Event #222: response.audio_transcript.delta
# 📝 Transcript delta: '!' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.357] Event #223: response.audio_transcript.delta
# 📝 Transcript delta: ' 🚀' (item: item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:39.365] Event #224: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.371] Event #225: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.375] Event #226: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:08:39.392] Event #227: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.400] Event #228: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.401] Event #229: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:08:39.432] Event #230: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.435] Event #231: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.441] Event #232: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:39.480] Event #233: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.493] Event #234: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.494] Event #235: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:39.508] Event #236: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.514] Event #237: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.525] Event #238: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.526] Event #239: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:08:39.552] Event #240: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.558] Event #241: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.566] Event #242: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.568] Event #243: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:08:39.604] Event #244: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.611] Event #245: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.621] Event #246: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.627] Event #247: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.634] Event #248: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:08:39.635] Event #249: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.643] Event #250: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.650] Event #251: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.655] Event #252: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:08:39.752] Event #253: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.762] Event #254: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.778] Event #255: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:39.790] Event #256: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.795] Event #257: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:39.804] Event #258: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.807] Event #259: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:39.807] Event #260: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.810] Event #261: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:39.817] Event #262: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.819] Event #263: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:39.836] Event #264: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.842] Event #265: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:39.923] Event #266: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.930] Event #267: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:39.937] Event #268: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.942] Event #269: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:39.944] Event #270: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.955] Event #271: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:39.972] Event #272: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.975] Event #273: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.976] Event #274: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:08:39.984] Event #275: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:39.992] Event #276: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:39.998] Event #277: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:08:40.012] Event #278: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.020] Event #279: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.023] Event #280: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:40.034] Event #281: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.042] Event #282: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.052] Event #283: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:40.085] Event #284: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.097] Event #285: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.099] Event #286: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.101] Event #287: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [00:08:40.108] Event #288: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.114] Event #289: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.129] Event #290: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.134] Event #291: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.136] Event #292: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [00:08:40.223] Event #293: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.234] Event #294: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.249] Event #295: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [00:08:40.252] Event #296: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.261] Event #297: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:40.266] Event #298: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.270] Event #299: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:40.279] Event #300: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.283] Event #301: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:40.294] Event #302: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.301] Event #303: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [00:08:40.310] Event #304: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.318] Event #305: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:40.327] Event #306: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.334] Event #307: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:40.356] Event #308: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.357] Event #309: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:40.373] Event #310: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.382] Event #311: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [00:08:40.388] Event #312: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [00:08:40.398] Event #313: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [00:08:40.403] Event #314: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [00:08:40.405] Event #315: response.audio.done
# ✅ Audio complete: item_2gkxiUkYIrY9yNyxsscXX8
# 📨 [00:08:40.407] Event #316: response.audio_transcript.done
# ❓ Unknown event: response.audio_transcript.done
# 📨 [00:08:40.409] Event #317: response.content_part.done
# ✅ Content part done: audio
# 📨 [00:08:40.412] Event #318: response.output_item.done
# ✅ Output item done: message (item_2gkxiUkYIrY9yNyxsscXX8)
# 📨 [00:08:40.414] Event #319: response.done
# ✅ Response complete: resp_3O5YEz97QKz5VbFr4e2eQj (status: cancelled)
# Quitting the chat...
#
# ============================================================
# 🛑 Shutting down agent application...
# ⏳ Waiting for threads to complete...
#    Stopping thread 1: AudioInput
#    ✅ Thread 1 (AudioInput) stopped
#    Stopping thread 2: AudioOutput
# Quitting the chat...
#
# ============================================================
# 🛑 Shutting down agent application...
# ⏳ Waiting for threads to complete...
#    Stopping thread 1: AudioInput
#    ✅ Thread 1 (AudioInput) stopped
#    Stopping thread 2: AudioOutput
# ✅ Audio playback thread completed (319 events processed)
#    ✅ Thread 2 (AudioOutput) stopped
# 🔌 Closing agent connection...
# 🔌 Closing WebSocket connection (ID: 0736c5e3)...
# ✅ Audio playback thread completed (319 events processed)
#    ✅ Thread 2 (AudioOutput) stopped
# 🔌 Closing agent connection...
# 🔌 Closing WebSocket connection (ID: 0736c5e3)...
# 🔌 WebSocket connection closed (ID: 0736c5e3)
#    Status: None, Message: None
# ✅ WebSocket thread stopped (ID: 0736c5e3)
# ✅ Connection closed (ID: 0736c5e3, 319 messages processed)
# ✅ Agent connection closed successfully
# ✅ Azure AI Agent Service application shutdown complete
# ============================================================
# 🔌 WebSocket connection closed (ID: 0736c5e3)
#    Status: None, Message: None
# ✅ WebSocket thread stopped (ID: 0736c5e3)
# ✅ Connection closed (ID: 0736c5e3, 319 messages processed)
# ✅ Agent connection closed successfully
# ✅ Azure AI Agent Service application shutdown complete
# ============================================================
